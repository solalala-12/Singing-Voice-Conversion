# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip3 install pydub
# Out:
# Collecting pydub
#   Downloading https://files.pythonhosted.org/packages/79/db/eaf620b73a1eec3c8c6f8f5b0b236a50f9da88ad57802154b7ba7664d0b8/pydub-0.23.1-py2.py3-none-any.whl
# Installing collected packages: pydub
# Successfully installed pydub-0.23.1

# %%
cd /content/drive/My\ Drive/tobigs/dnn_auto_encoder/music_makes_one
# Out:
# /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one

# %%
# from TFMusicAudioEncoder import process_data
import math
import tensorflow as tf
import numpy as np
from functools import partial
import importlib

#%%
### mp3로 변환하기(이미 했음)
# process_data.convert_mp3_to_wav()

#%%
LOSS_OUT_FILE = 'Epoch_Loss.txt'
# 파일 리스트 얻기
process_data.process_wav()


#%%
# Learning rate
lr = 0.0001

# L2 regularization
l2 = 0.0001

inputs = 12348
hidden_1_size = 8400
hidden_2_size = 3440
hidden_3_size = 2800

# Change the epochs variable to define the 
# number of times we iterate through all our batches
epochs = 10000

# Change the batch_size variable to define how many songs to load per batch
batch_size = 50

# Change the batches variable to change the number of batches you want per epoch
batches = 1

# Define our placeholder with shape [?, 12348]
X = tf.placeholder(tf.float32, shape=[None, inputs])
l2_regularizer = tf.contrib.layers.l2_regularizer(l2)

# partial 하면 저 변수가 들어간 상태로 둘 수 있지
autoencoder_dnn = partial(tf.layers.dense, 
						activation = tf.nn.elu,
						kernel_initializer = tf.contrib.layers.variance_scaling_initializer(),
						kernel_regularizer=  tf.contrib.layers.l2_regularizer(l2))

hidden_1 = autoencoder_dnn(X, hidden_1_size)
hidden_2 = autoencoder_dnn(hidden_1, hidden_2_size)
hidden_4 = autoencoder_dnn(hidden_2, hidden_3_size)
hidden_5 = autoencoder_dnn(hidden_4, hidden_2_size)
outputs =  autoencoder_dnn(hidden_5, inputs, activation=None)

reconstruction_loss = tf.reduce_mean(tf.square(outputs-X))

# 정규화에 더해지는 상수 값.
reg_loss = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
loss = tf.add_n([reconstruction_loss] + reg_loss)

# learning rate 두기
optimizer = tf.train.AdamOptimizer(lr)
training_op = optimizer.minimize(loss)
init = tf.global_variables_initializer()

#%%
def next_batch(c_batch, batch_size, sess):
	ch1_arr = []
	ch2_arr = []
	print(c_batch, batch_size)
	wav_arr_ch1, wav_arr_ch2, sample_rate = process_data.get_next_batch_original(c_batch, batch_size, sess)

	for sub_arr in wav_arr_ch1:
		batch_size_ch1 = math.floor(len(sub_arr)/inputs)
		sub_arr = sub_arr[:(batch_size_ch1*inputs)]
		ch1_arr.append(np.array(sub_arr).reshape(batch_size_ch1, inputs))

	for sub_arr in  wav_arr_ch2:
		batch_size_ch2 = math.floor(len(sub_arr)/inputs)
		sub_arr = sub_arr[:(batch_size_ch2*inputs)]
		ch2_arr.append(np.array(sub_arr).reshape(batch_size_ch2, inputs))

	return np.array(ch1_arr), np.array(ch2_arr), sample_rate

def next_batch2(c_batch, batch_size, sample_rate,sess):
	## 더 간단하게(file_to_data에서 전처리 했음)
	ch1_arr = []
	ch2_arr = []
	print(c_batch, batch_size)
	wav_arr_ch1, wav_arr_ch2, sample_rate = process_data.get_next_batch(c_batch, batch_size, sample_rate,sess)

	# inputs 단위로 잘라서 넣기
	for sub_arr in wav_arr_ch1:
		batch_size_ch1 = math.floor(len(sub_arr)/inputs)
		sub_arr = sub_arr[:(batch_size_ch1*inputs)]
		ch1_arr.append(np.array(sub_arr).reshape(batch_size_ch1, inputs))

	for sub_arr in  wav_arr_ch2:
		batch_size_ch2 = math.floor(len(sub_arr)/inputs)
		sub_arr = sub_arr[:(batch_size_ch2*inputs)]
		ch2_arr.append(np.array(sub_arr).reshape(batch_size_ch2, inputs))

	return np.array(ch1_arr), np.array(ch2_arr), sample_rate
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-5-1bac2a5bc074>:50: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.

# %% [markdown]
# # 처음부터 돌리기

# %%
cur_epoch = 0
##### Run training
with tf.Session() as sess:
	init.run()
	### saver 만들기
	saver = tf.train.Saver()
	sess.run(tf.global_variables_initializer())
	print('processing...')
	sample_rate = process_data.file_to_data(sess)
	# ckpt_path = saver.restore(sess, f"/content/drive/My Drive/tobigs/dnn_auto_encoder/saved/train{cur_epoch}")
	print('processing Done!')

	for epoch in range(cur_epoch+1,epochs):
		epoch_loss = []
		print("Epoch: " + str(epoch))
		for i in range(batches):
			ch1_song, ch2_song, sample_rate = next_batch2(i, batch_size, sample_rate,sess)
			# 두 채널 합치기
			total_songs = np.hstack([ch1_song, ch2_song])
			batch_loss = []

			for j in range(len(total_songs)):
				x_batch = total_songs[j]
				# 결과값과 비교하기
				_, l = sess.run([training_op, loss], feed_dict={X:x_batch})
				# 각 값들의 loss 구하기
				batch_loss.append(l)
				# print("Song loss: " + str(l))

			print("Curr Epoch: " + str(epoch) + " Curr Batch: " + str(i) + "/"+ str(batches))
			print("Batch Loss: " + str(np.mean(batch_loss)))
			epoch_loss.append(np.mean(batch_loss))
			
		print("Epoch Avg Loss: " + str(np.mean(epoch_loss)))

		if epoch % 500 == 0:
			ckpt_path = saver.save(sess, f'/content/drive/My Drive/tobigs/dnn_auto_encoder/saved/train{epoch}')

	ckpt_path = saver.save(sess, "/content/drive/My Drive/tobigs/dnn_auto_encoder/saved/train")
#9:10~9:30 100 epoch 간다.
# Out:
# processing...
# WARNING:tensorflow:From /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/process_data.py:45: The name tf.read_file is deprecated. Please use tf.io.read_file instead.
#
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/0.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/1.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/2.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/3.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/4.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/5.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/6.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/7.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/8.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/9.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/10.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/11.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/12.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/13.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/14.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/15.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/16.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/17.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/18.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/19.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/20.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/21.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/22.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/23.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/24.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/25.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/26.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/27.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/28.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/29.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/30.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/31.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/32.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/33.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/34.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/35.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/36.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/37.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/38.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/39.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/40.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/41.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/42.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/43.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/44.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/45.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/47.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/48.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/49.wav
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/50.wav
# processing Done!
# Epoch: 1
# 0 50
# Curr Epoch: 1 Curr Batch: 0/1
# Batch Loss: 212553.31
# Epoch Avg Loss: 212553.31
# Epoch: 2
# 0 50
# Curr Epoch: 2 Curr Batch: 0/1
# Batch Loss: 196517.6
# Epoch Avg Loss: 196517.6
# Epoch: 3
# 0 50
# Curr Epoch: 3 Curr Batch: 0/1
# Batch Loss: 194808.08
# Epoch Avg Loss: 194808.08
# Epoch: 4
# 0 50
# Curr Epoch: 4 Curr Batch: 0/1
# Batch Loss: 194248.31
# Epoch Avg Loss: 194248.31
# Epoch: 5
# 0 50
# Curr Epoch: 5 Curr Batch: 0/1
# Batch Loss: 193997.58
# Epoch Avg Loss: 193997.58
# Epoch: 6
# 0 50
# Curr Epoch: 6 Curr Batch: 0/1
# Batch Loss: 193804.72
# Epoch Avg Loss: 193804.72
# Epoch: 7
# 0 50
# Curr Epoch: 7 Curr Batch: 0/1
# Batch Loss: 193277.55
# Epoch Avg Loss: 193277.55
# Epoch: 8
# 0 50
# Curr Epoch: 8 Curr Batch: 0/1
# Batch Loss: 192878.22
# Epoch Avg Loss: 192878.22
# Epoch: 9
# 0 50
# Curr Epoch: 9 Curr Batch: 0/1
# Batch Loss: 191965.52
# Epoch Avg Loss: 191965.52
# Epoch: 10
# 0 50
# Curr Epoch: 10 Curr Batch: 0/1
# Batch Loss: 190942.5
# Epoch Avg Loss: 190942.5
# Epoch: 11
# 0 50
# Curr Epoch: 11 Curr Batch: 0/1
# Batch Loss: 189706.45
# Epoch Avg Loss: 189706.45
# Epoch: 12
# 0 50
# Curr Epoch: 12 Curr Batch: 0/1
# Batch Loss: 188686.58
# Epoch Avg Loss: 188686.58
# Epoch: 13
# 0 50
# Curr Epoch: 13 Curr Batch: 0/1
# Batch Loss: 187351.02
# Epoch Avg Loss: 187351.02
# Epoch: 14
# 0 50
# Curr Epoch: 14 Curr Batch: 0/1
# Batch Loss: 185776.14
# Epoch Avg Loss: 185776.14
# Epoch: 15
# 0 50
# Curr Epoch: 15 Curr Batch: 0/1
# Batch Loss: 183517.16
# Epoch Avg Loss: 183517.16
# Epoch: 16
# 0 50
# Curr Epoch: 16 Curr Batch: 0/1
# Batch Loss: 180191.58
# Epoch Avg Loss: 180191.58
# Epoch: 17
# 0 50
# Curr Epoch: 17 Curr Batch: 0/1
# Batch Loss: 179103.45
# Epoch Avg Loss: 179103.45
# Epoch: 18
# 0 50
# Curr Epoch: 18 Curr Batch: 0/1
# Batch Loss: 175700.3
# Epoch Avg Loss: 175700.3
# Epoch: 19
# 0 50
# Curr Epoch: 19 Curr Batch: 0/1
# Batch Loss: 172205.14
# Epoch Avg Loss: 172205.14
# Epoch: 20
# 0 50
# Curr Epoch: 20 Curr Batch: 0/1
# Batch Loss: 168566.9
# Epoch Avg Loss: 168566.9
# Epoch: 21
# 0 50
# Curr Epoch: 21 Curr Batch: 0/1
# Batch Loss: 165212.8
# Epoch Avg Loss: 165212.8
# Epoch: 22
# 0 50
# Curr Epoch: 22 Curr Batch: 0/1
# Batch Loss: 162948.19
# Epoch Avg Loss: 162948.19
# Epoch: 23
# 0 50
# Curr Epoch: 23 Curr Batch: 0/1
# Batch Loss: 159088.52
# Epoch Avg Loss: 159088.52
# Epoch: 24
# 0 50
# Curr Epoch: 24 Curr Batch: 0/1
# Batch Loss: 154917.4
# Epoch Avg Loss: 154917.4
# Epoch: 25
# 0 50
# Curr Epoch: 25 Curr Batch: 0/1
# Batch Loss: 149155.48
# Epoch Avg Loss: 149155.48
# Epoch: 26
# 0 50
# Curr Epoch: 26 Curr Batch: 0/1
# Batch Loss: 147303.86
# Epoch Avg Loss: 147303.86
# Epoch: 27
# 0 50
# Curr Epoch: 27 Curr Batch: 0/1
# Batch Loss: 142212.78
# Epoch Avg Loss: 142212.78
# Epoch: 28
# 0 50
# Curr Epoch: 28 Curr Batch: 0/1
# Batch Loss: 143933.05
# Epoch Avg Loss: 143933.05
# Epoch: 29
# 0 50
# Curr Epoch: 29 Curr Batch: 0/1
# Batch Loss: 134822.02
# Epoch Avg Loss: 134822.02
# Epoch: 30
# 0 50
# Curr Epoch: 30 Curr Batch: 0/1
# Batch Loss: 131812.1
# Epoch Avg Loss: 131812.1
# Epoch: 31
# 0 50
# Curr Epoch: 31 Curr Batch: 0/1
# Batch Loss: 123457.3
# Epoch Avg Loss: 123457.3
# Epoch: 32
# 0 50
# Curr Epoch: 32 Curr Batch: 0/1
# Batch Loss: 122728.55
# Epoch Avg Loss: 122728.55
# Epoch: 33
# 0 50
# Curr Epoch: 33 Curr Batch: 0/1
# Batch Loss: 120033.85
# Epoch Avg Loss: 120033.85
# Epoch: 34
# 0 50
# Curr Epoch: 34 Curr Batch: 0/1
# Batch Loss: 111655.49
# Epoch Avg Loss: 111655.49
# Epoch: 35
# 0 50
# Curr Epoch: 35 Curr Batch: 0/1
# Batch Loss: 109076.5
# Epoch Avg Loss: 109076.5
# Epoch: 36
# 0 50
# Curr Epoch: 36 Curr Batch: 0/1
# Batch Loss: 107327.19
# Epoch Avg Loss: 107327.19
# Epoch: 37
# 0 50
# Curr Epoch: 37 Curr Batch: 0/1
# Batch Loss: 105307.24
# Epoch Avg Loss: 105307.24
# Epoch: 38
# 0 50
# Curr Epoch: 38 Curr Batch: 0/1
# Batch Loss: 102852.46
# Epoch Avg Loss: 102852.46
# Epoch: 39
# 0 50
# Curr Epoch: 39 Curr Batch: 0/1
# Batch Loss: 99204.99
# Epoch Avg Loss: 99204.99
# Epoch: 40
# 0 50
# Curr Epoch: 40 Curr Batch: 0/1
# Batch Loss: 98731.38
# Epoch Avg Loss: 98731.38
# Epoch: 41
# 0 50
# Curr Epoch: 41 Curr Batch: 0/1
# Batch Loss: 93179.95
# Epoch Avg Loss: 93179.95
# Epoch: 42
# 0 50
# Curr Epoch: 42 Curr Batch: 0/1
# Batch Loss: 94579.78
# Epoch Avg Loss: 94579.78
# Epoch: 43
# 0 50
# Curr Epoch: 43 Curr Batch: 0/1
# Batch Loss: 90075.96
# Epoch Avg Loss: 90075.96
# Epoch: 44
# 0 50
# Curr Epoch: 44 Curr Batch: 0/1
# Batch Loss: 91513.05
# Epoch Avg Loss: 91513.05
# Epoch: 45
# 0 50
# Curr Epoch: 45 Curr Batch: 0/1
# Batch Loss: 90066.43
# Epoch Avg Loss: 90066.43
# Epoch: 46
# 0 50
# Curr Epoch: 46 Curr Batch: 0/1
# Batch Loss: 89941.89
# Epoch Avg Loss: 89941.89
# Epoch: 47
# 0 50
# Curr Epoch: 47 Curr Batch: 0/1
# Batch Loss: 86636.94
# Epoch Avg Loss: 86636.94
# Epoch: 48
# 0 50
# Curr Epoch: 48 Curr Batch: 0/1
# Batch Loss: 88643.26
# Epoch Avg Loss: 88643.26
# Epoch: 49
# 0 50
# Curr Epoch: 49 Curr Batch: 0/1
# Batch Loss: 84536.77
# Epoch Avg Loss: 84536.77
# Epoch: 50
# 0 50
# Curr Epoch: 50 Curr Batch: 0/1
# Batch Loss: 86659.96
# Epoch Avg Loss: 86659.96
# Epoch: 51
# 0 50
# Curr Epoch: 51 Curr Batch: 0/1
# Batch Loss: 84872.85
# Epoch Avg Loss: 84872.85
# Epoch: 52
# 0 50
# Curr Epoch: 52 Curr Batch: 0/1
# Batch Loss: 82188.92
# Epoch Avg Loss: 82188.92
# Epoch: 53
# 0 50
# Curr Epoch: 53 Curr Batch: 0/1
# Batch Loss: 82199.555
# Epoch Avg Loss: 82199.555
# Epoch: 54
# 0 50
# Curr Epoch: 54 Curr Batch: 0/1
# Batch Loss: 83051.984
# Epoch Avg Loss: 83051.984
# Epoch: 55
# 0 50
# Curr Epoch: 55 Curr Batch: 0/1
# Batch Loss: 80684.055
# Epoch Avg Loss: 80684.055
# Epoch: 56
# 0 50
# Curr Epoch: 56 Curr Batch: 0/1
# Batch Loss: 81281.95
# Epoch Avg Loss: 81281.95
# Epoch: 57
# 0 50
# Curr Epoch: 57 Curr Batch: 0/1
# Batch Loss: 78883.47
# Epoch Avg Loss: 78883.47
# Epoch: 58
# 0 50
# Curr Epoch: 58 Curr Batch: 0/1
# Batch Loss: 80423.78
# Epoch Avg Loss: 80423.78
# Epoch: 59
# 0 50
# Curr Epoch: 59 Curr Batch: 0/1
# Batch Loss: 79858.21
# Epoch Avg Loss: 79858.21
# Epoch: 60
# 0 50
# Curr Epoch: 60 Curr Batch: 0/1
# Batch Loss: 78714.445
# Epoch Avg Loss: 78714.445
# Epoch: 61
# 0 50
# Curr Epoch: 61 Curr Batch: 0/1
# Batch Loss: 79538.9
# Epoch Avg Loss: 79538.9
# Epoch: 62
# 0 50
# Curr Epoch: 62 Curr Batch: 0/1
# Batch Loss: 79364.65
# Epoch Avg Loss: 79364.65
# Epoch: 63
# 0 50
# Curr Epoch: 63 Curr Batch: 0/1
# Batch Loss: 77655.125
# Epoch Avg Loss: 77655.125
# Epoch: 64
# 0 50
# Curr Epoch: 64 Curr Batch: 0/1
# Batch Loss: 75894.56
# Epoch Avg Loss: 75894.56
# Epoch: 65
# 0 50
# Curr Epoch: 65 Curr Batch: 0/1
# Batch Loss: 77233.71
# Epoch Avg Loss: 77233.71
# Epoch: 66
# 0 50
# Curr Epoch: 66 Curr Batch: 0/1
# Batch Loss: 76997.516
# Epoch Avg Loss: 76997.516
# Epoch: 67
# 0 50
# Curr Epoch: 67 Curr Batch: 0/1
# Batch Loss: 76439.88
# Epoch Avg Loss: 76439.88
# Epoch: 68
# 0 50
# Curr Epoch: 68 Curr Batch: 0/1
# Batch Loss: 76239.766
# Epoch Avg Loss: 76239.766
# Epoch: 69
# 0 50
# Curr Epoch: 69 Curr Batch: 0/1
# Batch Loss: 75357.1
# Epoch Avg Loss: 75357.1
# Epoch: 70
# 0 50
# Curr Epoch: 70 Curr Batch: 0/1
# Batch Loss: 75837.45
# Epoch Avg Loss: 75837.45
# Epoch: 71
# 0 50
# Curr Epoch: 71 Curr Batch: 0/1
# Batch Loss: 75242.01
# Epoch Avg Loss: 75242.01
# Epoch: 72
# 0 50
# Curr Epoch: 72 Curr Batch: 0/1
# Batch Loss: 75446.7
# Epoch Avg Loss: 75446.7
# Epoch: 73
# 0 50
# Curr Epoch: 73 Curr Batch: 0/1
# Batch Loss: 74182.07
# Epoch Avg Loss: 74182.07
# Epoch: 74
# 0 50
# Curr Epoch: 74 Curr Batch: 0/1
# Batch Loss: 73705.21
# Epoch Avg Loss: 73705.21
# Epoch: 75
# 0 50
# Curr Epoch: 75 Curr Batch: 0/1
# Batch Loss: 72046.97
# Epoch Avg Loss: 72046.97
# Epoch: 76
# 0 50
# Curr Epoch: 76 Curr Batch: 0/1
# Batch Loss: 72753.8
# Epoch Avg Loss: 72753.8
# Epoch: 77
# 0 50
# Curr Epoch: 77 Curr Batch: 0/1
# Batch Loss: 72338.516
# Epoch Avg Loss: 72338.516
# Epoch: 78
# 0 50
# Curr Epoch: 78 Curr Batch: 0/1
# Batch Loss: 73001.83
# Epoch Avg Loss: 73001.83
# Epoch: 79
# 0 50
# Curr Epoch: 79 Curr Batch: 0/1
# Batch Loss: 70396.734
# Epoch Avg Loss: 70396.734
# Epoch: 80
# 0 50
# Curr Epoch: 80 Curr Batch: 0/1
# Batch Loss: 70920.92
# Epoch Avg Loss: 70920.92
# Epoch: 81
# 0 50
# Curr Epoch: 81 Curr Batch: 0/1
# Batch Loss: 71659.04
# Epoch Avg Loss: 71659.04
# Epoch: 82
# 0 50
# Curr Epoch: 82 Curr Batch: 0/1
# Batch Loss: 69679.85
# Epoch Avg Loss: 69679.85
# Epoch: 83
# 0 50
# Curr Epoch: 83 Curr Batch: 0/1
# Batch Loss: 71011.3
# Epoch Avg Loss: 71011.3
# Epoch: 84
# 0 50
# Curr Epoch: 84 Curr Batch: 0/1
# Batch Loss: 69426.88
# Epoch Avg Loss: 69426.88
# Epoch: 85
# 0 50
# Curr Epoch: 85 Curr Batch: 0/1
# Batch Loss: 68416.62
# Epoch Avg Loss: 68416.62
# Epoch: 86
# 0 50
# Curr Epoch: 86 Curr Batch: 0/1
# Batch Loss: 68655.82
# Epoch Avg Loss: 68655.82
# Epoch: 87
# 0 50
# Curr Epoch: 87 Curr Batch: 0/1
# Batch Loss: 68589.71
# Epoch Avg Loss: 68589.71
# Epoch: 88
# 0 50
# Curr Epoch: 88 Curr Batch: 0/1
# Batch Loss: 69023.55
# Epoch Avg Loss: 69023.55
# Epoch: 89
# 0 50
# Curr Epoch: 89 Curr Batch: 0/1
# Batch Loss: 67297.664
# Epoch Avg Loss: 67297.664
# Epoch: 90
# 0 50
# Curr Epoch: 90 Curr Batch: 0/1
# Batch Loss: 67505.47
# Epoch Avg Loss: 67505.47
# Epoch: 91
# 0 50
# Curr Epoch: 91 Curr Batch: 0/1
# Batch Loss: 69042.57
# Epoch Avg Loss: 69042.57
# Epoch: 92
# 0 50
# Curr Epoch: 92 Curr Batch: 0/1
# Batch Loss: 66706.016
# Epoch Avg Loss: 66706.016
# Epoch: 93
# 0 50
# Curr Epoch: 93 Curr Batch: 0/1
# Batch Loss: 66705.18
# Epoch Avg Loss: 66705.18
# Epoch: 94
# 0 50
# Curr Epoch: 94 Curr Batch: 0/1
# Batch Loss: 65927.35
# Epoch Avg Loss: 65927.35
# Epoch: 95
# 0 50
# Curr Epoch: 95 Curr Batch: 0/1
# Batch Loss: 66033.15
# Epoch Avg Loss: 66033.15
# Epoch: 96
# 0 50
# Curr Epoch: 96 Curr Batch: 0/1
# Batch Loss: 66616.98
# Epoch Avg Loss: 66616.98
# Epoch: 97
# 0 50
# Curr Epoch: 97 Curr Batch: 0/1
# Batch Loss: 64442.37
# Epoch Avg Loss: 64442.37
# Epoch: 98
# 0 50
# Curr Epoch: 98 Curr Batch: 0/1
# Batch Loss: 64918.26
# Epoch Avg Loss: 64918.26
# Epoch: 99
# 0 50
# Curr Epoch: 99 Curr Batch: 0/1
# Batch Loss: 65191.51
# Epoch Avg Loss: 65191.51
# Epoch: 100
# 0 50
# Curr Epoch: 100 Curr Batch: 0/1
# Batch Loss: 64850.414
# Epoch Avg Loss: 64850.414
# Epoch: 101
# 0 50
# Curr Epoch: 101 Curr Batch: 0/1
# Batch Loss: 64260.88
# Epoch Avg Loss: 64260.88
# Epoch: 102
# 0 50
# Curr Epoch: 102 Curr Batch: 0/1
# Batch Loss: 63213.07
# Epoch Avg Loss: 63213.07
# Epoch: 103
# 0 50
# Curr Epoch: 103 Curr Batch: 0/1
# Batch Loss: 64045.547
# Epoch Avg Loss: 64045.547
# Epoch: 104
# 0 50
# Curr Epoch: 104 Curr Batch: 0/1
# Batch Loss: 62913.703
# Epoch Avg Loss: 62913.703
# Epoch: 105
# 0 50
# Curr Epoch: 105 Curr Batch: 0/1
# Batch Loss: 63139.547
# Epoch Avg Loss: 63139.547
# Epoch: 106
# 0 50
# Curr Epoch: 106 Curr Batch: 0/1
# Batch Loss: 62240.773
# Epoch Avg Loss: 62240.773
# Epoch: 107
# 0 50
# Curr Epoch: 107 Curr Batch: 0/1
# Batch Loss: 62745.055
# Epoch Avg Loss: 62745.055
# Epoch: 108
# 0 50
# Curr Epoch: 108 Curr Batch: 0/1
# Batch Loss: 62300.355
# Epoch Avg Loss: 62300.355
# Epoch: 109
# 0 50
# Curr Epoch: 109 Curr Batch: 0/1
# Batch Loss: 62103.78
# Epoch Avg Loss: 62103.78
# Epoch: 110
# 0 50
# Curr Epoch: 110 Curr Batch: 0/1
# Batch Loss: 61779.88
# Epoch Avg Loss: 61779.88
# Epoch: 111
# 0 50
# Curr Epoch: 111 Curr Batch: 0/1
# Batch Loss: 60891.574
# Epoch Avg Loss: 60891.574
# Epoch: 112
# 0 50
# Curr Epoch: 112 Curr Batch: 0/1
# Batch Loss: 60960.344
# Epoch Avg Loss: 60960.344
# Epoch: 113
# 0 50
# Curr Epoch: 113 Curr Batch: 0/1
# Batch Loss: 60523.64
# Epoch Avg Loss: 60523.64
# Epoch: 114
# 0 50
# Curr Epoch: 114 Curr Batch: 0/1
# Batch Loss: 60624.504
# Epoch Avg Loss: 60624.504
# Epoch: 115
# 0 50
# Curr Epoch: 115 Curr Batch: 0/1
# Batch Loss: 60459.77
# Epoch Avg Loss: 60459.77
# Epoch: 116
# 0 50
# Curr Epoch: 116 Curr Batch: 0/1
# Batch Loss: 61316.047
# Epoch Avg Loss: 61316.047
# Epoch: 117
# 0 50
# Curr Epoch: 117 Curr Batch: 0/1
# Batch Loss: 59351.29
# Epoch Avg Loss: 59351.29
# Epoch: 118
# 0 50
# Curr Epoch: 118 Curr Batch: 0/1
# Batch Loss: 59867.74
# Epoch Avg Loss: 59867.74
# Epoch: 119
# 0 50
# Curr Epoch: 119 Curr Batch: 0/1
# Batch Loss: 58660.44
# Epoch Avg Loss: 58660.44
# Epoch: 120
# 0 50
# Curr Epoch: 120 Curr Batch: 0/1
# Batch Loss: 59420.566
# Epoch Avg Loss: 59420.566
# Epoch: 121
# 0 50
# Curr Epoch: 121 Curr Batch: 0/1
# Batch Loss: 57950.87
# Epoch Avg Loss: 57950.87
# Epoch: 122
# 0 50
# Curr Epoch: 122 Curr Batch: 0/1
# Batch Loss: 58795.855
# Epoch Avg Loss: 58795.855
# Epoch: 123
# 0 50
# Curr Epoch: 123 Curr Batch: 0/1
# Batch Loss: 57492.29
# Epoch Avg Loss: 57492.29
# Epoch: 124
# 0 50
# Curr Epoch: 124 Curr Batch: 0/1
# Batch Loss: 58155.53
# Epoch Avg Loss: 58155.53
# Epoch: 125
# 0 50
# Curr Epoch: 125 Curr Batch: 0/1
# Batch Loss: 56926.504
# Epoch Avg Loss: 56926.504
# Epoch: 126
# 0 50
# Curr Epoch: 126 Curr Batch: 0/1
# Batch Loss: 57533.773
# Epoch Avg Loss: 57533.773
# Epoch: 127
# 0 50
# Curr Epoch: 127 Curr Batch: 0/1
# Batch Loss: 56763.926
# Epoch Avg Loss: 56763.926
# Epoch: 128
# 0 50
# Curr Epoch: 128 Curr Batch: 0/1
# Batch Loss: 57082.355
# Epoch Avg Loss: 57082.355
# Epoch: 129
# 0 50
# Curr Epoch: 129 Curr Batch: 0/1
# Batch Loss: 56109.74
# Epoch Avg Loss: 56109.74
# Epoch: 130
# 0 50
# Curr Epoch: 130 Curr Batch: 0/1
# Batch Loss: 56322.95
# Epoch Avg Loss: 56322.95
# Epoch: 131
# 0 50
# Curr Epoch: 131 Curr Batch: 0/1
# Batch Loss: 55804.195
# Epoch Avg Loss: 55804.195
# Epoch: 132
# 0 50
# Curr Epoch: 132 Curr Batch: 0/1
# Batch Loss: 55747.684
# Epoch Avg Loss: 55747.684
# Epoch: 133
# 0 50
# Curr Epoch: 133 Curr Batch: 0/1
# Batch Loss: 55226.1
# Epoch Avg Loss: 55226.1
# Epoch: 134
# 0 50
# Curr Epoch: 134 Curr Batch: 0/1
# Batch Loss: 55583.094
# Epoch Avg Loss: 55583.094
# Epoch: 135
# 0 50
# Curr Epoch: 135 Curr Batch: 0/1
# Batch Loss: 54922.875
# Epoch Avg Loss: 54922.875
# Epoch: 136
# 0 50
# Curr Epoch: 136 Curr Batch: 0/1
# Batch Loss: 55274.926
# Epoch Avg Loss: 55274.926
# Epoch: 137
# 0 50
# Curr Epoch: 137 Curr Batch: 0/1
# Batch Loss: 54296.26
# Epoch Avg Loss: 54296.26
# Epoch: 138
# 0 50
# Curr Epoch: 138 Curr Batch: 0/1
# Batch Loss: 54864.58
# Epoch Avg Loss: 54864.58
# Epoch: 139
# 0 50
# Curr Epoch: 139 Curr Batch: 0/1
# Batch Loss: 54055.57
# Epoch Avg Loss: 54055.57
# Epoch: 140
# 0 50
# Curr Epoch: 140 Curr Batch: 0/1
# Batch Loss: 54694.96
# Epoch Avg Loss: 54694.96
# Epoch: 141
# 0 50
# Curr Epoch: 141 Curr Batch: 0/1
# Batch Loss: 53392.656
# Epoch Avg Loss: 53392.656
# Epoch: 142
# 0 50
# Curr Epoch: 142 Curr Batch: 0/1
# Batch Loss: 54376.35
# Epoch Avg Loss: 54376.35
# Epoch: 143
# 0 50
# Curr Epoch: 143 Curr Batch: 0/1
# Batch Loss: 52977.97
# Epoch Avg Loss: 52977.97
# Epoch: 144
# 0 50
# Curr Epoch: 144 Curr Batch: 0/1
# Batch Loss: 53398.15
# Epoch Avg Loss: 53398.15
# Epoch: 145
# 0 50
# Curr Epoch: 145 Curr Batch: 0/1
# Batch Loss: 52300.613
# Epoch Avg Loss: 52300.613
# Epoch: 146
# 0 50
# Curr Epoch: 146 Curr Batch: 0/1
# Batch Loss: 53003.227
# Epoch Avg Loss: 53003.227
# Epoch: 147
# 0 50
# Curr Epoch: 147 Curr Batch: 0/1
# Batch Loss: 52100.87
# Epoch Avg Loss: 52100.87
# Epoch: 148
# 0 50
# Curr Epoch: 148 Curr Batch: 0/1
# Batch Loss: 52818.76
# Epoch Avg Loss: 52818.76
# Epoch: 149
# 0 50
# Curr Epoch: 149 Curr Batch: 0/1
# Batch Loss: 51677.59
# Epoch Avg Loss: 51677.59
# Epoch: 150
# 0 50
# Curr Epoch: 150 Curr Batch: 0/1
# Batch Loss: 52199.08
# Epoch Avg Loss: 52199.08
# Epoch: 151
# 0 50
# Curr Epoch: 151 Curr Batch: 0/1
# Batch Loss: 51088.566
# Epoch Avg Loss: 51088.566
# Epoch: 152
# 0 50
# Curr Epoch: 152 Curr Batch: 0/1
# Batch Loss: 51438.805
# Epoch Avg Loss: 51438.805
# Epoch: 153
# 0 50
# Curr Epoch: 153 Curr Batch: 0/1
# Batch Loss: 50927.91
# Epoch Avg Loss: 50927.91
# Epoch: 154
# 0 50
# Curr Epoch: 154 Curr Batch: 0/1
# Batch Loss: 51502.4
# Epoch Avg Loss: 51502.4
# Epoch: 155
# 0 50
# Curr Epoch: 155 Curr Batch: 0/1
# Batch Loss: 50727.65
# Epoch Avg Loss: 50727.65
# Epoch: 156
# 0 50
# Curr Epoch: 156 Curr Batch: 0/1
# Batch Loss: 51724.965
# Epoch Avg Loss: 51724.965
# Epoch: 157
# 0 50
# Curr Epoch: 157 Curr Batch: 0/1
# Batch Loss: 50297.4
# Epoch Avg Loss: 50297.4
# Epoch: 158
# 0 50
# Curr Epoch: 158 Curr Batch: 0/1
# Batch Loss: 50739.79
# Epoch Avg Loss: 50739.79
# Epoch: 159
# 0 50
# Curr Epoch: 159 Curr Batch: 0/1
# Batch Loss: 50422.465
# Epoch Avg Loss: 50422.465
# Epoch: 160
# 0 50
# Curr Epoch: 160 Curr Batch: 0/1
# Batch Loss: 49915.285
# Epoch Avg Loss: 49915.285
# Epoch: 161
# 0 50
# Curr Epoch: 161 Curr Batch: 0/1
# Batch Loss: 49461.234
# Epoch Avg Loss: 49461.234
# Epoch: 162
# 0 50
# Curr Epoch: 162 Curr Batch: 0/1
# Batch Loss: 49699.76
# Epoch Avg Loss: 49699.76
# Epoch: 163
# 0 50
# Curr Epoch: 163 Curr Batch: 0/1
# Batch Loss: 49486.363
# Epoch Avg Loss: 49486.363
# Epoch: 164
# 0 50
# Curr Epoch: 164 Curr Batch: 0/1
# Batch Loss: 49613.13
# Epoch Avg Loss: 49613.13
# Epoch: 165
# 0 50
# Curr Epoch: 165 Curr Batch: 0/1
# Batch Loss: 49333.965
# Epoch Avg Loss: 49333.965
# Epoch: 166
# 0 50
# Curr Epoch: 166 Curr Batch: 0/1
# Batch Loss: 49371.895
# Epoch Avg Loss: 49371.895
# Epoch: 167
# 0 50
# Curr Epoch: 167 Curr Batch: 0/1
# Batch Loss: 49053.32
# Epoch Avg Loss: 49053.32
# Epoch: 168
# 0 50
# Curr Epoch: 168 Curr Batch: 0/1
# Batch Loss: 49135.246
# Epoch Avg Loss: 49135.246
# Epoch: 169
# 0 50
# Curr Epoch: 169 Curr Batch: 0/1
# Batch Loss: 48281.234
# Epoch Avg Loss: 48281.234
# Epoch: 170
# 0 50
# Curr Epoch: 170 Curr Batch: 0/1
# Batch Loss: 48781.74
# Epoch Avg Loss: 48781.74
# Epoch: 171
# 0 50
# Curr Epoch: 171 Curr Batch: 0/1
# Batch Loss: 47826.734
# Epoch Avg Loss: 47826.734
# Epoch: 172
# 0 50
# Curr Epoch: 172 Curr Batch: 0/1
# Batch Loss: 48285.406
# Epoch Avg Loss: 48285.406
# Epoch: 173
# 0 50
# Curr Epoch: 173 Curr Batch: 0/1
# Batch Loss: 47519.855
# Epoch Avg Loss: 47519.855
# Epoch: 174
# 0 50
# Curr Epoch: 174 Curr Batch: 0/1
# Batch Loss: 47983.47
# Epoch Avg Loss: 47983.47
# Epoch: 175
# 0 50
# Curr Epoch: 175 Curr Batch: 0/1
# Batch Loss: 47149.316
# Epoch Avg Loss: 47149.316
# Epoch: 176
# 0 50
# Curr Epoch: 176 Curr Batch: 0/1
# Batch Loss: 47118.79
# Epoch Avg Loss: 47118.79
# Epoch: 177
# 0 50
# Curr Epoch: 177 Curr Batch: 0/1
# Batch Loss: 46675.02
# Epoch Avg Loss: 46675.02
# Epoch: 178
# 0 50
# Curr Epoch: 178 Curr Batch: 0/1
# Batch Loss: 46595.65
# Epoch Avg Loss: 46595.65
# Epoch: 179
# 0 50
# Curr Epoch: 179 Curr Batch: 0/1
# Batch Loss: 46530.95
# Epoch Avg Loss: 46530.95
# Epoch: 180
# 0 50
# Curr Epoch: 180 Curr Batch: 0/1
# Batch Loss: 46208.68
# Epoch Avg Loss: 46208.68
# Epoch: 181
# 0 50
# Curr Epoch: 181 Curr Batch: 0/1
# Batch Loss: 46283.715
# Epoch Avg Loss: 46283.715
# Epoch: 182
# 0 50
# Curr Epoch: 182 Curr Batch: 0/1
# Batch Loss: 46239.227
# Epoch Avg Loss: 46239.227
# Epoch: 183
# 0 50
# Curr Epoch: 183 Curr Batch: 0/1
# Batch Loss: 45997.84
# Epoch Avg Loss: 45997.84
# Epoch: 184
# 0 50
# Curr Epoch: 184 Curr Batch: 0/1
# Batch Loss: 46506.45
# Epoch Avg Loss: 46506.45
# Epoch: 185
# 0 50
# Curr Epoch: 185 Curr Batch: 0/1
# Batch Loss: 46135.87
# Epoch Avg Loss: 46135.87
# Epoch: 186
# 0 50
# Curr Epoch: 186 Curr Batch: 0/1
# Batch Loss: 46508.664
# Epoch Avg Loss: 46508.664
# Epoch: 187
# 0 50
# Curr Epoch: 187 Curr Batch: 0/1
# Batch Loss: 45819.227
# Epoch Avg Loss: 45819.227
# Epoch: 188
# 0 50
# Curr Epoch: 188 Curr Batch: 0/1
# Batch Loss: 46145.4
# Epoch Avg Loss: 46145.4
# Epoch: 189
# 0 50
# Curr Epoch: 189 Curr Batch: 0/1
# Batch Loss: 45585.53
# Epoch Avg Loss: 45585.53
# Epoch: 190
# 0 50
# Curr Epoch: 190 Curr Batch: 0/1
# Batch Loss: 45809.85
# Epoch Avg Loss: 45809.85
# Epoch: 191
# 0 50
# Curr Epoch: 191 Curr Batch: 0/1
# Batch Loss: 44892.85
# Epoch Avg Loss: 44892.85
# Epoch: 192
# 0 50
# Curr Epoch: 192 Curr Batch: 0/1
# Batch Loss: 45423.535
# Epoch Avg Loss: 45423.535
# Epoch: 193
# 0 50
# Curr Epoch: 193 Curr Batch: 0/1
# Batch Loss: 44833.82
# Epoch Avg Loss: 44833.82
# Epoch: 194
# 0 50
# Curr Epoch: 194 Curr Batch: 0/1
# Batch Loss: 45183.27
# Epoch Avg Loss: 45183.27
# Epoch: 195
# 0 50
# Curr Epoch: 195 Curr Batch: 0/1
# Batch Loss: 44369.965
# Epoch Avg Loss: 44369.965
# Epoch: 196
# 0 50
# Curr Epoch: 196 Curr Batch: 0/1
# Batch Loss: 44624.766
# Epoch Avg Loss: 44624.766
# Epoch: 197
# 0 50
# Curr Epoch: 197 Curr Batch: 0/1
# Batch Loss: 43833.324
# Epoch Avg Loss: 43833.324
# Epoch: 198
# 0 50
# Curr Epoch: 198 Curr Batch: 0/1
# Batch Loss: 44156.23
# Epoch Avg Loss: 44156.23
# Epoch: 199
# 0 50
# Curr Epoch: 199 Curr Batch: 0/1
# Batch Loss: 43839.695
# Epoch Avg Loss: 43839.695
# Epoch: 200
# 0 50
# Curr Epoch: 200 Curr Batch: 0/1
# Batch Loss: 43965.086
# Epoch Avg Loss: 43965.086
# Epoch: 201
# 0 50
# Curr Epoch: 201 Curr Batch: 0/1
# Batch Loss: 43507.04
# Epoch Avg Loss: 43507.04
# Epoch: 202
# 0 50
# Curr Epoch: 202 Curr Batch: 0/1
# Batch Loss: 43478.426
# Epoch Avg Loss: 43478.426
# Epoch: 203
# 0 50
# Curr Epoch: 203 Curr Batch: 0/1
# Batch Loss: 43174.82
# Epoch Avg Loss: 43174.82
# Epoch: 204
# 0 50
# Curr Epoch: 204 Curr Batch: 0/1
# Batch Loss: 43255.535
# Epoch Avg Loss: 43255.535
# Epoch: 205
# 0 50
# Curr Epoch: 205 Curr Batch: 0/1
# Batch Loss: 43083.406
# Epoch Avg Loss: 43083.406
# Epoch: 206
# 0 50
# Curr Epoch: 206 Curr Batch: 0/1
# Batch Loss: 43137.09
# Epoch Avg Loss: 43137.09
# Epoch: 207
# 0 50
# Curr Epoch: 207 Curr Batch: 0/1
# Batch Loss: 42790.785
# Epoch Avg Loss: 42790.785
# Epoch: 208
# 0 50
# Curr Epoch: 208 Curr Batch: 0/1
# Batch Loss: 42630.52
# Epoch Avg Loss: 42630.52
# Epoch: 209
# 0 50
# Curr Epoch: 209 Curr Batch: 0/1
# Batch Loss: 42496.137
# Epoch Avg Loss: 42496.137
# Epoch: 210
# 0 50
# Curr Epoch: 210 Curr Batch: 0/1
# Batch Loss: 42497.113
# Epoch Avg Loss: 42497.113
# Epoch: 211
# 0 50
# Curr Epoch: 211 Curr Batch: 0/1
# Batch Loss: 42632.254
# Epoch Avg Loss: 42632.254
# Epoch: 212
# 0 50
# Curr Epoch: 212 Curr Batch: 0/1
# Batch Loss: 42533.89
# Epoch Avg Loss: 42533.89
# Epoch: 213
# 0 50
# Curr Epoch: 213 Curr Batch: 0/1
# Batch Loss: 42572.39
# Epoch Avg Loss: 42572.39
# Epoch: 214
# 0 50
# Curr Epoch: 214 Curr Batch: 0/1
# Batch Loss: 42533.977
# Epoch Avg Loss: 42533.977
# Epoch: 215
# 0 50
# Curr Epoch: 215 Curr Batch: 0/1
# Batch Loss: 42176.22
# Epoch Avg Loss: 42176.22
# Epoch: 216
# 0 50
# Curr Epoch: 216 Curr Batch: 0/1
# Batch Loss: 42482.65
# Epoch Avg Loss: 42482.65
# Epoch: 217
# 0 50
# Curr Epoch: 217 Curr Batch: 0/1
# Batch Loss: 41892.414
# Epoch Avg Loss: 41892.414
# Epoch: 218
# 0 50
# Curr Epoch: 218 Curr Batch: 0/1
# Batch Loss: 42510.11
# Epoch Avg Loss: 42510.11
# Epoch: 219
# 0 50
# Curr Epoch: 219 Curr Batch: 0/1
# Batch Loss: 41602.324
# Epoch Avg Loss: 41602.324
# Epoch: 220
# 0 50
# Curr Epoch: 220 Curr Batch: 0/1
# Batch Loss: 42415.637
# Epoch Avg Loss: 42415.637
# Epoch: 221
# 0 50
# Curr Epoch: 221 Curr Batch: 0/1
# Batch Loss: 41106.41
# Epoch Avg Loss: 41106.41
# Epoch: 222
# 0 50
# Curr Epoch: 222 Curr Batch: 0/1
# Batch Loss: 42213.61
# Epoch Avg Loss: 42213.61
# Epoch: 223
# 0 50
# Curr Epoch: 223 Curr Batch: 0/1
# Batch Loss: 41045.94
# Epoch Avg Loss: 41045.94
# Epoch: 224
# 0 50
# Curr Epoch: 224 Curr Batch: 0/1
# Batch Loss: 41995.746
# Epoch Avg Loss: 41995.746
# Epoch: 225
# 0 50
# Curr Epoch: 225 Curr Batch: 0/1
# Batch Loss: 40798.55
# Epoch Avg Loss: 40798.55
# Epoch: 226
# 0 50
# Curr Epoch: 226 Curr Batch: 0/1
# Batch Loss: 41331.77
# Epoch Avg Loss: 41331.77
# Epoch: 227
# 0 50
# Curr Epoch: 227 Curr Batch: 0/1
# Batch Loss: 40629.992
# Epoch Avg Loss: 40629.992
# Epoch: 228
# 0 50
# Curr Epoch: 228 Curr Batch: 0/1
# Batch Loss: 40985.31
# Epoch Avg Loss: 40985.31
# Epoch: 229
# 0 50
# Curr Epoch: 229 Curr Batch: 0/1
# Batch Loss: 40409.97
# Epoch Avg Loss: 40409.97
# Epoch: 230
# 0 50
# Curr Epoch: 230 Curr Batch: 0/1
# Batch Loss: 40646.24
# Epoch Avg Loss: 40646.24
# Epoch: 231
# 0 50
# Curr Epoch: 231 Curr Batch: 0/1
# Batch Loss: 40062.977
# Epoch Avg Loss: 40062.977
# Epoch: 232
# 0 50
# Curr Epoch: 232 Curr Batch: 0/1
# Batch Loss: 40115.156
# Epoch Avg Loss: 40115.156
# Epoch: 233
# 0 50
# Curr Epoch: 233 Curr Batch: 0/1
# Batch Loss: 39889.79
# Epoch Avg Loss: 39889.79
# Epoch: 234
# 0 50
# Curr Epoch: 234 Curr Batch: 0/1
# Batch Loss: 40087.55
# Epoch Avg Loss: 40087.55
# Epoch: 235
# 0 50
# Curr Epoch: 235 Curr Batch: 0/1
# Batch Loss: 40004.477
# Epoch Avg Loss: 40004.477
# Epoch: 236
# 0 50
# Curr Epoch: 236 Curr Batch: 0/1
# Batch Loss: 40112.65
# Epoch Avg Loss: 40112.65
# Epoch: 237
# 0 50
# Curr Epoch: 237 Curr Batch: 0/1
# Batch Loss: 40200.05
# Epoch Avg Loss: 40200.05
# Epoch: 238
# 0 50
# Curr Epoch: 238 Curr Batch: 0/1
# Batch Loss: 40474.81
# Epoch Avg Loss: 40474.81
# Epoch: 239
# 0 50
# Curr Epoch: 239 Curr Batch: 0/1
# Batch Loss: 39987.316
# Epoch Avg Loss: 39987.316
# Epoch: 240
# 0 50
# Curr Epoch: 240 Curr Batch: 0/1
# Batch Loss: 40087.754
# Epoch Avg Loss: 40087.754
# Epoch: 241
# 0 50
# Curr Epoch: 241 Curr Batch: 0/1
# Batch Loss: 39828.934
# Epoch Avg Loss: 39828.934
# Epoch: 242
# 0 50
# Curr Epoch: 242 Curr Batch: 0/1
# Batch Loss: 39897.14
# Epoch Avg Loss: 39897.14
# Epoch: 243
# 0 50
# Curr Epoch: 243 Curr Batch: 0/1
# Batch Loss: 39417.61
# Epoch Avg Loss: 39417.61
# Epoch: 244
# 0 50
# Curr Epoch: 244 Curr Batch: 0/1
# Batch Loss: 40026.984
# Epoch Avg Loss: 40026.984
# Epoch: 245
# 0 50
# Curr Epoch: 245 Curr Batch: 0/1
# Batch Loss: 39301.285
# Epoch Avg Loss: 39301.285
# Epoch: 246
# 0 50
# Curr Epoch: 246 Curr Batch: 0/1
# Batch Loss: 40218.766
# Epoch Avg Loss: 40218.766
# Epoch: 247
# 0 50
# Curr Epoch: 247 Curr Batch: 0/1
# Batch Loss: 39061.33
# Epoch Avg Loss: 39061.33
# Epoch: 248
# 0 50
# Curr Epoch: 248 Curr Batch: 0/1
# Batch Loss: 40125.74
# Epoch Avg Loss: 40125.74
# Epoch: 249
# 0 50
# Curr Epoch: 249 Curr Batch: 0/1
# Batch Loss: 39132.086
# Epoch Avg Loss: 39132.086
# Epoch: 250
# 0 50
# Curr Epoch: 250 Curr Batch: 0/1
# Batch Loss: 39988.49
# Epoch Avg Loss: 39988.49
# Epoch: 251
# 0 50
# Curr Epoch: 251 Curr Batch: 0/1
# Batch Loss: 38939.19
# Epoch Avg Loss: 38939.19
# Epoch: 252
# 0 50
# Curr Epoch: 252 Curr Batch: 0/1
# Batch Loss: 39031.035
# Epoch Avg Loss: 39031.035
# Epoch: 253
# 0 50
# Curr Epoch: 253 Curr Batch: 0/1
# Batch Loss: 38538.234
# Epoch Avg Loss: 38538.234
# Epoch: 254
# 0 50
# Curr Epoch: 254 Curr Batch: 0/1
# Batch Loss: 38638.555
# Epoch Avg Loss: 38638.555
# Epoch: 255
# 0 50
# Curr Epoch: 255 Curr Batch: 0/1
# Batch Loss: 38353.04
# Epoch Avg Loss: 38353.04
# Epoch: 256
# 0 50
# Curr Epoch: 256 Curr Batch: 0/1
# Batch Loss: 38169.848
# Epoch Avg Loss: 38169.848
# Epoch: 257
# 0 50
# Curr Epoch: 257 Curr Batch: 0/1
# Batch Loss: 38264.066
# Epoch Avg Loss: 38264.066
# Epoch: 258
# 0 50
# Curr Epoch: 258 Curr Batch: 0/1
# Batch Loss: 37766.434
# Epoch Avg Loss: 37766.434
# Epoch: 259
# 0 50
# Curr Epoch: 259 Curr Batch: 0/1
# Batch Loss: 37822.72
# Epoch Avg Loss: 37822.72
# Epoch: 260
# 0 50
# Curr Epoch: 260 Curr Batch: 0/1
# Batch Loss: 37657.715
# Epoch Avg Loss: 37657.715
# Epoch: 261
# 0 50
# Curr Epoch: 261 Curr Batch: 0/1
# Batch Loss: 38003.035
# Epoch Avg Loss: 38003.035
# Epoch: 262
# 0 50
# Curr Epoch: 262 Curr Batch: 0/1
# Batch Loss: 37976.016
# Epoch Avg Loss: 37976.016
# Epoch: 263
# 0 50
# Curr Epoch: 263 Curr Batch: 0/1
# Batch Loss: 37831.598
# Epoch Avg Loss: 37831.598
# Epoch: 264
# 0 50
# Curr Epoch: 264 Curr Batch: 0/1
# Batch Loss: 38202.87
# Epoch Avg Loss: 38202.87
# Epoch: 265
# 0 50
# Curr Epoch: 265 Curr Batch: 0/1
# Batch Loss: 37967.074
# Epoch Avg Loss: 37967.074
# Epoch: 266
# 0 50
# Curr Epoch: 266 Curr Batch: 0/1
# Batch Loss: 38528.45
# Epoch Avg Loss: 38528.45
# Epoch: 267
# 0 50
# Curr Epoch: 267 Curr Batch: 0/1
# Batch Loss: 38069.984
# Epoch Avg Loss: 38069.984
# Epoch: 268
# 0 50
# Curr Epoch: 268 Curr Batch: 0/1
# Batch Loss: 38991.094
# Epoch Avg Loss: 38991.094
# Epoch: 269
# 0 50
# Curr Epoch: 269 Curr Batch: 0/1
# Batch Loss: 38337.883
# Epoch Avg Loss: 38337.883
# Epoch: 270
# 0 50
# Curr Epoch: 270 Curr Batch: 0/1
# Batch Loss: 39032.38
# Epoch Avg Loss: 39032.38
# Epoch: 271
# 0 50
# Curr Epoch: 271 Curr Batch: 0/1
# Batch Loss: 37510.246
# Epoch Avg Loss: 37510.246
# Epoch: 272
# 0 50
# Curr Epoch: 272 Curr Batch: 0/1
# Batch Loss: 38268.773
# Epoch Avg Loss: 38268.773
# Epoch: 273
# 0 50
# Curr Epoch: 273 Curr Batch: 0/1
# Batch Loss: 37062.74
# Epoch Avg Loss: 37062.74
# Epoch: 274
# 0 50
# Curr Epoch: 274 Curr Batch: 0/1
# Batch Loss: 37634.836
# Epoch Avg Loss: 37634.836
# Epoch: 275
# 0 50
# Curr Epoch: 275 Curr Batch: 0/1
# Batch Loss: 36656.56
# Epoch Avg Loss: 36656.56
# Epoch: 276
# 0 50
# Curr Epoch: 276 Curr Batch: 0/1
# Batch Loss: 37173.953
# Epoch Avg Loss: 37173.953
# Epoch: 277
# 0 50
# Curr Epoch: 277 Curr Batch: 0/1
# Batch Loss: 36446.508
# Epoch Avg Loss: 36446.508
# Epoch: 278
# 0 50
# Curr Epoch: 278 Curr Batch: 0/1
# Batch Loss: 36765.96
# Epoch Avg Loss: 36765.96
# Epoch: 279
# 0 50
# Curr Epoch: 279 Curr Batch: 0/1
# Batch Loss: 36130.836
# Epoch Avg Loss: 36130.836
# Epoch: 280
# 0 50
# Curr Epoch: 280 Curr Batch: 0/1
# Batch Loss: 36656.332
# Epoch Avg Loss: 36656.332
# Epoch: 281
# 0 50
# Curr Epoch: 281 Curr Batch: 0/1
# Batch Loss: 36265.37
# Epoch Avg Loss: 36265.37
# Epoch: 282
# 0 50
# Curr Epoch: 282 Curr Batch: 0/1
# Batch Loss: 36376.242
# Epoch Avg Loss: 36376.242
# Epoch: 283
# 0 50
# Curr Epoch: 283 Curr Batch: 0/1
# Batch Loss: 36260.902
# Epoch Avg Loss: 36260.902
# Epoch: 284
# 0 50
# Curr Epoch: 284 Curr Batch: 0/1
# Batch Loss: 36350.34
# Epoch Avg Loss: 36350.34
# Epoch: 285
# 0 50
# Curr Epoch: 285 Curr Batch: 0/1
# Batch Loss: 36293.97
# Epoch Avg Loss: 36293.97
# Epoch: 286
# 0 50
# Curr Epoch: 286 Curr Batch: 0/1
# Batch Loss: 35947.875
# Epoch Avg Loss: 35947.875
# Epoch: 287
# 0 50
# Curr Epoch: 287 Curr Batch: 0/1
# Batch Loss: 36362.344
# Epoch Avg Loss: 36362.344
# Epoch: 288
# 0 50
# Curr Epoch: 288 Curr Batch: 0/1
# Batch Loss: 36214.5
# Epoch Avg Loss: 36214.5
# Epoch: 289
# 0 50
# Curr Epoch: 289 Curr Batch: 0/1
# Batch Loss: 36402.95
# Epoch Avg Loss: 36402.95
# Epoch: 290
# 0 50
# Curr Epoch: 290 Curr Batch: 0/1
# Batch Loss: 36019.82
# Epoch Avg Loss: 36019.82
# Epoch: 291
# 0 50
# Curr Epoch: 291 Curr Batch: 0/1
# Batch Loss: 36296.37
# Epoch Avg Loss: 36296.37
# Epoch: 292
# 0 50
# Curr Epoch: 292 Curr Batch: 0/1
# Batch Loss: 36563.684
# Epoch Avg Loss: 36563.684
# Epoch: 293
# 0 50
# Curr Epoch: 293 Curr Batch: 0/1
# Batch Loss: 36533.383
# Epoch Avg Loss: 36533.383
# Epoch: 294
# 0 50
# Curr Epoch: 294 Curr Batch: 0/1
# Batch Loss: 36685.418
# Epoch Avg Loss: 36685.418
# Epoch: 295
# 0 50
# Curr Epoch: 295 Curr Batch: 0/1
# Batch Loss: 36215.69
# Epoch Avg Loss: 36215.69
# Epoch: 296
# 0 50
# Curr Epoch: 296 Curr Batch: 0/1
# Batch Loss: 36696.465
# Epoch Avg Loss: 36696.465
# Epoch: 297
# 0 50
# Curr Epoch: 297 Curr Batch: 0/1
# Batch Loss: 36347.453
# Epoch Avg Loss: 36347.453
# Epoch: 298
# 0 50
# Curr Epoch: 298 Curr Batch: 0/1
# Batch Loss: 36526.57
# Epoch Avg Loss: 36526.57
# Epoch: 299
# 0 50
# Curr Epoch: 299 Curr Batch: 0/1
# Batch Loss: 35771.652
# Epoch Avg Loss: 35771.652
# Epoch: 300
# 0 50
# Curr Epoch: 300 Curr Batch: 0/1
# Batch Loss: 36277.723
# Epoch Avg Loss: 36277.723
# Epoch: 301
# 0 50
# Curr Epoch: 301 Curr Batch: 0/1
# Batch Loss: 35567.066
# Epoch Avg Loss: 35567.066
# Epoch: 302
# 0 50
# Curr Epoch: 302 Curr Batch: 0/1
# Batch Loss: 35922.414
# Epoch Avg Loss: 35922.414
# Epoch: 303
# 0 50
# Curr Epoch: 303 Curr Batch: 0/1
# Batch Loss: 35480.12
# Epoch Avg Loss: 35480.12
# Epoch: 304
# 0 50
# Curr Epoch: 304 Curr Batch: 0/1
# Batch Loss: 35484.965
# Epoch Avg Loss: 35484.965
# Epoch: 305
# 0 50
# Curr Epoch: 305 Curr Batch: 0/1
# Batch Loss: 35339.586
# Epoch Avg Loss: 35339.586
# Epoch: 306
# 0 50
# Curr Epoch: 306 Curr Batch: 0/1
# Batch Loss: 35063.35
# Epoch Avg Loss: 35063.35
# Epoch: 307
# 0 50
# Curr Epoch: 307 Curr Batch: 0/1
# Batch Loss: 35146.66
# Epoch Avg Loss: 35146.66
# Epoch: 308
# 0 50
# Curr Epoch: 308 Curr Batch: 0/1
# Batch Loss: 34719.797
# Epoch Avg Loss: 34719.797
# Epoch: 309
# 0 50
# Curr Epoch: 309 Curr Batch: 0/1
# Batch Loss: 35388.05
# Epoch Avg Loss: 35388.05
# Epoch: 310
# 0 50
# Curr Epoch: 310 Curr Batch: 0/1
# Batch Loss: 34769.742
# Epoch Avg Loss: 34769.742
# Epoch: 311
# 0 50
# Curr Epoch: 311 Curr Batch: 0/1
# Batch Loss: 35476.145
# Epoch Avg Loss: 35476.145
# Epoch: 312
# 0 50
# Curr Epoch: 312 Curr Batch: 0/1
# Batch Loss: 34626.516
# Epoch Avg Loss: 34626.516
# Epoch: 313
# 0 50
# Curr Epoch: 313 Curr Batch: 0/1
# Batch Loss: 35287.85
# Epoch Avg Loss: 35287.85
# Epoch: 314
# 0 50
# Curr Epoch: 314 Curr Batch: 0/1
# Batch Loss: 34641.848
# Epoch Avg Loss: 34641.848
# Epoch: 315
# 0 50
# Curr Epoch: 315 Curr Batch: 0/1
# Batch Loss: 35586.906
# Epoch Avg Loss: 35586.906
# Epoch: 316
# 0 50
# Curr Epoch: 316 Curr Batch: 0/1
# Batch Loss: 35386.49
# Epoch Avg Loss: 35386.49
# Epoch: 317
# 0 50
# Curr Epoch: 317 Curr Batch: 0/1
# Batch Loss: 35966.64
# Epoch Avg Loss: 35966.64
# Epoch: 318
# 0 50
# Curr Epoch: 318 Curr Batch: 0/1
# Batch Loss: 35943.246
# Epoch Avg Loss: 35943.246
# Epoch: 319
# 0 50
# Curr Epoch: 319 Curr Batch: 0/1
# Batch Loss: 35205.69
# Epoch Avg Loss: 35205.69
# Epoch: 320
# 0 50
# Curr Epoch: 320 Curr Batch: 0/1
# Batch Loss: 35535.754
# Epoch Avg Loss: 35535.754
# Epoch: 321
# 0 50
# Curr Epoch: 321 Curr Batch: 0/1
# Batch Loss: 34766.457
# Epoch Avg Loss: 34766.457
# Epoch: 322
# 0 50
# Curr Epoch: 322 Curr Batch: 0/1
# Batch Loss: 35020.266
# Epoch Avg Loss: 35020.266
# Epoch: 323
# 0 50
# Curr Epoch: 323 Curr Batch: 0/1
# Batch Loss: 34101.664
# Epoch Avg Loss: 34101.664
# Epoch: 324
# 0 50
# Curr Epoch: 324 Curr Batch: 0/1
# Batch Loss: 34459.258
# Epoch Avg Loss: 34459.258
# Epoch: 325
# 0 50
# Curr Epoch: 325 Curr Batch: 0/1
# Batch Loss: 33815.266
# Epoch Avg Loss: 33815.266
# Epoch: 326
# 0 50
# Curr Epoch: 326 Curr Batch: 0/1
# Batch Loss: 34256.402
# Epoch Avg Loss: 34256.402
# Epoch: 327
# 0 50
# Curr Epoch: 327 Curr Batch: 0/1
# Batch Loss: 33642.01
# Epoch Avg Loss: 33642.01
# Epoch: 328
# 0 50
# Curr Epoch: 328 Curr Batch: 0/1
# Batch Loss: 34128.086
# Epoch Avg Loss: 34128.086
# Epoch: 329
# 0 50
# Curr Epoch: 329 Curr Batch: 0/1
# Batch Loss: 33745.297
# Epoch Avg Loss: 33745.297
# Epoch: 330
# 0 50
# Curr Epoch: 330 Curr Batch: 0/1
# Batch Loss: 34288.113
# Epoch Avg Loss: 34288.113
# Epoch: 331
# 0 50
# Curr Epoch: 331 Curr Batch: 0/1
# Batch Loss: 33969.47
# Epoch Avg Loss: 33969.47
# Epoch: 332
# 0 50
# Curr Epoch: 332 Curr Batch: 0/1
# Batch Loss: 34440.926
# Epoch Avg Loss: 34440.926
# Epoch: 333
# 0 50
# Curr Epoch: 333 Curr Batch: 0/1
# Batch Loss: 33707.38
# Epoch Avg Loss: 33707.38
# Epoch: 334
# 0 50
# Curr Epoch: 334 Curr Batch: 0/1
# Batch Loss: 34087.066
# Epoch Avg Loss: 34087.066
# Epoch: 335
# 0 50
# Curr Epoch: 335 Curr Batch: 0/1
# Batch Loss: 33848.28
# Epoch Avg Loss: 33848.28
# Epoch: 336
# 0 50
# Curr Epoch: 336 Curr Batch: 0/1
# Batch Loss: 33887.375
# Epoch Avg Loss: 33887.375
# Epoch: 337
# 0 50
# Curr Epoch: 337 Curr Batch: 0/1
# Batch Loss: 33754.906
# Epoch Avg Loss: 33754.906
# Epoch: 338
# 0 50
# Curr Epoch: 338 Curr Batch: 0/1
# Batch Loss: 33704.27
# Epoch Avg Loss: 33704.27
# Epoch: 339
# 0 50
# Curr Epoch: 339 Curr Batch: 0/1
# Batch Loss: 33666.58
# Epoch Avg Loss: 33666.58
# Epoch: 340
# 0 50
# Curr Epoch: 340 Curr Batch: 0/1
# Batch Loss: 33702.258
# Epoch Avg Loss: 33702.258
# Epoch: 341
# 0 50
# Curr Epoch: 341 Curr Batch: 0/1
# Batch Loss: 33937.72
# Epoch Avg Loss: 33937.72
# Epoch: 342
# 0 50
# Curr Epoch: 342 Curr Batch: 0/1
# Batch Loss: 33745.273
# Epoch Avg Loss: 33745.273
# Epoch: 343
# 0 50
# Curr Epoch: 343 Curr Batch: 0/1
# Batch Loss: 33867.977
# Epoch Avg Loss: 33867.977
# Epoch: 344
# 0 50
# Curr Epoch: 344 Curr Batch: 0/1
# Batch Loss: 33425.996
# Epoch Avg Loss: 33425.996
# Epoch: 345
# 0 50
# Curr Epoch: 345 Curr Batch: 0/1
# Batch Loss: 33688.285
# Epoch Avg Loss: 33688.285
# Epoch: 346
# 0 50
# Curr Epoch: 346 Curr Batch: 0/1
# Batch Loss: 33152.13
# Epoch Avg Loss: 33152.13
# Epoch: 347
# 0 50
# Curr Epoch: 347 Curr Batch: 0/1
# Batch Loss: 33435.477
# Epoch Avg Loss: 33435.477
# Epoch: 348
# 0 50
# Curr Epoch: 348 Curr Batch: 0/1
# Batch Loss: 32868.887
# Epoch Avg Loss: 32868.887
# Epoch: 349
# 0 50
# Curr Epoch: 349 Curr Batch: 0/1
# Batch Loss: 33464.36
# Epoch Avg Loss: 33464.36
# Epoch: 350
# 0 50
# Curr Epoch: 350 Curr Batch: 0/1
# Batch Loss: 32845.105
# Epoch Avg Loss: 32845.105
# Epoch: 351
# 0 50
# Curr Epoch: 351 Curr Batch: 0/1
# Batch Loss: 33489.54
# Epoch Avg Loss: 33489.54
# Epoch: 352
# 0 50
# Curr Epoch: 352 Curr Batch: 0/1
# Batch Loss: 32956.734
# Epoch Avg Loss: 32956.734
# Epoch: 353
# 0 50
# Curr Epoch: 353 Curr Batch: 0/1
# Batch Loss: 33312.52
# Epoch Avg Loss: 33312.52
# Epoch: 354
# 0 50
# Curr Epoch: 354 Curr Batch: 0/1
# Batch Loss: 33012.656
# Epoch Avg Loss: 33012.656
# Epoch: 355
# 0 50
# Curr Epoch: 355 Curr Batch: 0/1
# Batch Loss: 33096.816
# Epoch Avg Loss: 33096.816
# Epoch: 356
# 0 50
# Curr Epoch: 356 Curr Batch: 0/1
# Batch Loss: 33329.01
# Epoch Avg Loss: 33329.01
# Epoch: 357
# 0 50
# Curr Epoch: 357 Curr Batch: 0/1
# Batch Loss: 33041.88
# Epoch Avg Loss: 33041.88
# Epoch: 358
# 0 50
# Curr Epoch: 358 Curr Batch: 0/1
# Batch Loss: 33306.47
# Epoch Avg Loss: 33306.47
# Epoch: 359
# 0 50
# Curr Epoch: 359 Curr Batch: 0/1
# Batch Loss: 32696.64
# Epoch Avg Loss: 32696.64
# Epoch: 360
# 0 50
# Curr Epoch: 360 Curr Batch: 0/1
# Batch Loss: 32768.43
# Epoch Avg Loss: 32768.43
# Epoch: 361
# 0 50
# Curr Epoch: 361 Curr Batch: 0/1
# Batch Loss: 32498.22
# Epoch Avg Loss: 32498.22
# Epoch: 362
# 0 50
# Curr Epoch: 362 Curr Batch: 0/1
# Batch Loss: 32802.945
# Epoch Avg Loss: 32802.945
# Epoch: 363
# 0 50
# Curr Epoch: 363 Curr Batch: 0/1
# Batch Loss: 32537.018
# Epoch Avg Loss: 32537.018
# Epoch: 364
# 0 50
# Curr Epoch: 364 Curr Batch: 0/1
# Batch Loss: 32795.934
# Epoch Avg Loss: 32795.934
# Epoch: 365
# 0 50
# Curr Epoch: 365 Curr Batch: 0/1
# Batch Loss: 32648.035
# Epoch Avg Loss: 32648.035
# Epoch: 366
# 0 50
# Curr Epoch: 366 Curr Batch: 0/1
# Batch Loss: 32675.775
# Epoch Avg Loss: 32675.775
# Epoch: 367
# 0 50
# Curr Epoch: 367 Curr Batch: 0/1
# Batch Loss: 32429.74
# Epoch Avg Loss: 32429.74
# Epoch: 368
# 0 50
# Curr Epoch: 368 Curr Batch: 0/1
# Batch Loss: 32471.152
# Epoch Avg Loss: 32471.152
# Epoch: 369
# 0 50
# Curr Epoch: 369 Curr Batch: 0/1
# Batch Loss: 32259.807
# Epoch Avg Loss: 32259.807
# Epoch: 370
# 0 50
# Curr Epoch: 370 Curr Batch: 0/1
# Batch Loss: 32064.5
# Epoch Avg Loss: 32064.5
# Epoch: 371
# 0 50
# Curr Epoch: 371 Curr Batch: 0/1
# Batch Loss: 31986.287
# Epoch Avg Loss: 31986.287
# Epoch: 372
# 0 50
# Curr Epoch: 372 Curr Batch: 0/1
# Batch Loss: 31789.717
# Epoch Avg Loss: 31789.717
# Epoch: 373
# 0 50
# Curr Epoch: 373 Curr Batch: 0/1
# Batch Loss: 31936.287
# Epoch Avg Loss: 31936.287
# Epoch: 374
# 0 50
# Curr Epoch: 374 Curr Batch: 0/1
# Batch Loss: 31692.46
# Epoch Avg Loss: 31692.46
# Epoch: 375
# 0 50
# Curr Epoch: 375 Curr Batch: 0/1
# Batch Loss: 31932.703
# Epoch Avg Loss: 31932.703
# Epoch: 376
# 0 50
# Curr Epoch: 376 Curr Batch: 0/1
# Batch Loss: 31950.283
# Epoch Avg Loss: 31950.283
# Epoch: 377
# 0 50
# Curr Epoch: 377 Curr Batch: 0/1
# Batch Loss: 32255.734
# Epoch Avg Loss: 32255.734
# Epoch: 378
# 0 50
# Curr Epoch: 378 Curr Batch: 0/1
# Batch Loss: 32265.336
# Epoch Avg Loss: 32265.336
# Epoch: 379
# 0 50
# Curr Epoch: 379 Curr Batch: 0/1
# Batch Loss: 32208.092
# Epoch Avg Loss: 32208.092
# Epoch: 380
# 0 50
# Curr Epoch: 380 Curr Batch: 0/1
# Batch Loss: 32581.86
# Epoch Avg Loss: 32581.86
# Epoch: 381
# 0 50
# Curr Epoch: 381 Curr Batch: 0/1
# Batch Loss: 32274.03
# Epoch Avg Loss: 32274.03
# Epoch: 382
# 0 50
# Curr Epoch: 382 Curr Batch: 0/1
# Batch Loss: 32902.457
# Epoch Avg Loss: 32902.457
# Epoch: 383
# 0 50
# Curr Epoch: 383 Curr Batch: 0/1
# Batch Loss: 32154.686
# Epoch Avg Loss: 32154.686
# Epoch: 384
# 0 50
# Curr Epoch: 384 Curr Batch: 0/1
# Batch Loss: 32879.094
# Epoch Avg Loss: 32879.094
# Epoch: 385
# 0 50
# Curr Epoch: 385 Curr Batch: 0/1
# Batch Loss: 32299.027
# Epoch Avg Loss: 32299.027
# Epoch: 386
# 0 50
# Curr Epoch: 386 Curr Batch: 0/1
# Batch Loss: 32434.38
# Epoch Avg Loss: 32434.38
# Epoch: 387
# 0 50
# Curr Epoch: 387 Curr Batch: 0/1
# Batch Loss: 31690.578
# Epoch Avg Loss: 31690.578
# Epoch: 388
# 0 50
# Curr Epoch: 388 Curr Batch: 0/1
# Batch Loss: 31723.936
# Epoch Avg Loss: 31723.936
# Epoch: 389
# 0 50
# Curr Epoch: 389 Curr Batch: 0/1
# Batch Loss: 31400.814
# Epoch Avg Loss: 31400.814
# Epoch: 390
# 0 50
# Curr Epoch: 390 Curr Batch: 0/1
# Batch Loss: 31295.373
# Epoch Avg Loss: 31295.373
# Epoch: 391
# 0 50
# Curr Epoch: 391 Curr Batch: 0/1
# Batch Loss: 30983.77
# Epoch Avg Loss: 30983.77
# Epoch: 392
# 0 50
# Curr Epoch: 392 Curr Batch: 0/1
# Batch Loss: 30852.123
# Epoch Avg Loss: 30852.123
# Epoch: 393
# 0 50
# Curr Epoch: 393 Curr Batch: 0/1
# Batch Loss: 30789.59
# Epoch Avg Loss: 30789.59
# Epoch: 394
# 0 50
# Curr Epoch: 394 Curr Batch: 0/1
# Batch Loss: 30725.346
# Epoch Avg Loss: 30725.346
# Epoch: 395
# 0 50
# Curr Epoch: 395 Curr Batch: 0/1
# Batch Loss: 30875.814
# Epoch Avg Loss: 30875.814
# Epoch: 396
# 0 50
# Curr Epoch: 396 Curr Batch: 0/1
# Batch Loss: 31145.59
# Epoch Avg Loss: 31145.59
# Epoch: 397
# 0 50
# Curr Epoch: 397 Curr Batch: 0/1
# Batch Loss: 31317.285
# Epoch Avg Loss: 31317.285
# Epoch: 398
# 0 50
# Curr Epoch: 398 Curr Batch: 0/1
# Batch Loss: 31752.572
# Epoch Avg Loss: 31752.572
# Epoch: 399
# 0 50
# Curr Epoch: 399 Curr Batch: 0/1
# Batch Loss: 31915.318
# Epoch Avg Loss: 31915.318
# Epoch: 400
# 0 50
# Curr Epoch: 400 Curr Batch: 0/1
# Batch Loss: 32717.234
# Epoch Avg Loss: 32717.234
# Epoch: 401
# 0 50
# Curr Epoch: 401 Curr Batch: 0/1
# Batch Loss: 32685.205
# Epoch Avg Loss: 32685.205
# Epoch: 402
# 0 50
# Curr Epoch: 402 Curr Batch: 0/1
# Batch Loss: 33625.547
# Epoch Avg Loss: 33625.547
# Epoch: 403
# 0 50
# Curr Epoch: 403 Curr Batch: 0/1
# Batch Loss: 31996.18
# Epoch Avg Loss: 31996.18
# Epoch: 404
# 0 50
# Curr Epoch: 404 Curr Batch: 0/1
# Batch Loss: 32557.758
# Epoch Avg Loss: 32557.758
# Epoch: 405
# 0 50
# Curr Epoch: 405 Curr Batch: 0/1
# Batch Loss: 31683.016
# Epoch Avg Loss: 31683.016
# Epoch: 406
# 0 50
# Curr Epoch: 406 Curr Batch: 0/1
# Batch Loss: 31625.475
# Epoch Avg Loss: 31625.475
# Epoch: 407
# 0 50
# Curr Epoch: 407 Curr Batch: 0/1
# Batch Loss: 30848.33
# Epoch Avg Loss: 30848.33
# Epoch: 408
# 0 50
# Curr Epoch: 408 Curr Batch: 0/1
# Batch Loss: 30847.732
# Epoch Avg Loss: 30847.732
# Epoch: 409
# 0 50
# Curr Epoch: 409 Curr Batch: 0/1
# Batch Loss: 30520.402
# Epoch Avg Loss: 30520.402
# Epoch: 410
# 0 50
# Curr Epoch: 410 Curr Batch: 0/1
# Batch Loss: 30358.693
# Epoch Avg Loss: 30358.693
# Epoch: 411
# 0 50
# Curr Epoch: 411 Curr Batch: 0/1
# Batch Loss: 30132.127
# Epoch Avg Loss: 30132.127
# Epoch: 412
# 0 50
# Curr Epoch: 412 Curr Batch: 0/1
# Batch Loss: 30077.762
# Epoch Avg Loss: 30077.762
# Epoch: 413
# 0 50
# Curr Epoch: 413 Curr Batch: 0/1
# Batch Loss: 29965.475
# Epoch Avg Loss: 29965.475
# Epoch: 414
# 0 50
# Curr Epoch: 414 Curr Batch: 0/1
# Batch Loss: 29964.043
# Epoch Avg Loss: 29964.043
# Epoch: 415
# 0 50
# Curr Epoch: 415 Curr Batch: 0/1
# Batch Loss: 29819.287
# Epoch Avg Loss: 29819.287
# Epoch: 416
# 0 50
# Curr Epoch: 416 Curr Batch: 0/1
# Batch Loss: 29753.818
# Epoch Avg Loss: 29753.818
# Epoch: 417
# 0 50
# Curr Epoch: 417 Curr Batch: 0/1
# Batch Loss: 29907.252
# Epoch Avg Loss: 29907.252
# Epoch: 418
# 0 50
# Curr Epoch: 418 Curr Batch: 0/1
# Batch Loss: 29798.508
# Epoch Avg Loss: 29798.508
# Epoch: 419
# 0 50
# Curr Epoch: 419 Curr Batch: 0/1
# Batch Loss: 30123.047
# Epoch Avg Loss: 30123.047
# Epoch: 420
# 0 50
# Curr Epoch: 420 Curr Batch: 0/1
# Batch Loss: 30037.652
# Epoch Avg Loss: 30037.652
# Epoch: 421
# 0 50
# Curr Epoch: 421 Curr Batch: 0/1
# Batch Loss: 30339.96
# Epoch Avg Loss: 30339.96
# Epoch: 422
# 0 50
# Curr Epoch: 422 Curr Batch: 0/1
# Batch Loss: 30536.643
# Epoch Avg Loss: 30536.643
# Epoch: 423
# 0 50
# Curr Epoch: 423 Curr Batch: 0/1
# Batch Loss: 30521.467
# Epoch Avg Loss: 30521.467
# Epoch: 424
# 0 50
# Curr Epoch: 424 Curr Batch: 0/1
# Batch Loss: 31117.61
# Epoch Avg Loss: 31117.61
# Epoch: 425
# 0 50
# Curr Epoch: 425 Curr Batch: 0/1
# Batch Loss: 31068.613
# Epoch Avg Loss: 31068.613
# Epoch: 426
# 0 50
# Curr Epoch: 426 Curr Batch: 0/1
# Batch Loss: 31522.523
# Epoch Avg Loss: 31522.523
# Epoch: 427
# 0 50
# Curr Epoch: 427 Curr Batch: 0/1
# Batch Loss: 31307.664
# Epoch Avg Loss: 31307.664
# Epoch: 428
# 0 50
# Curr Epoch: 428 Curr Batch: 0/1
# Batch Loss: 31661.914
# Epoch Avg Loss: 31661.914
# Epoch: 429
# 0 50
# Curr Epoch: 429 Curr Batch: 0/1
# Batch Loss: 31453.477
# Epoch Avg Loss: 31453.477
# Epoch: 430
# 0 50
# Curr Epoch: 430 Curr Batch: 0/1
# Batch Loss: 31335.57
# Epoch Avg Loss: 31335.57
# Epoch: 431
# 0 50
# Curr Epoch: 431 Curr Batch: 0/1
# Batch Loss: 30765.564
# Epoch Avg Loss: 30765.564
# Epoch: 432
# 0 50
# Curr Epoch: 432 Curr Batch: 0/1
# Batch Loss: 30207.29
# Epoch Avg Loss: 30207.29
# Epoch: 433
# 0 50
# Curr Epoch: 433 Curr Batch: 0/1
# Batch Loss: 30107.893
# Epoch Avg Loss: 30107.893
# Epoch: 434
# 0 50
# Curr Epoch: 434 Curr Batch: 0/1
# Batch Loss: 29481.258
# Epoch Avg Loss: 29481.258
# Epoch: 435
# 0 50
# Curr Epoch: 435 Curr Batch: 0/1
# Batch Loss: 29529.547
# Epoch Avg Loss: 29529.547
# Epoch: 436
# 0 50
# Curr Epoch: 436 Curr Batch: 0/1
# Batch Loss: 29194.07
# Epoch Avg Loss: 29194.07
# Epoch: 437
# 0 50
# Curr Epoch: 437 Curr Batch: 0/1
# Batch Loss: 29433.09
# Epoch Avg Loss: 29433.09
# Epoch: 438
# 0 50
# Curr Epoch: 438 Curr Batch: 0/1
# Batch Loss: 29475.295
# Epoch Avg Loss: 29475.295
# Epoch: 439
# 0 50
# Curr Epoch: 439 Curr Batch: 0/1
# Batch Loss: 29758.148
# Epoch Avg Loss: 29758.148
# Epoch: 440
# 0 50
# Curr Epoch: 440 Curr Batch: 0/1
# Batch Loss: 29913.252
# Epoch Avg Loss: 29913.252
# Epoch: 441
# 0 50
# Curr Epoch: 441 Curr Batch: 0/1
# Batch Loss: 29833.74
# Epoch Avg Loss: 29833.74
# Epoch: 442
# 0 50
# Curr Epoch: 442 Curr Batch: 0/1
# Batch Loss: 30565.82
# Epoch Avg Loss: 30565.82
# Epoch: 443
# 0 50
# Curr Epoch: 443 Curr Batch: 0/1
# Batch Loss: 30104.336
# Epoch Avg Loss: 30104.336
# Epoch: 444
# 0 50
# Curr Epoch: 444 Curr Batch: 0/1
# Batch Loss: 30991.352
# Epoch Avg Loss: 30991.352
# Epoch: 445
# 0 50
# Curr Epoch: 445 Curr Batch: 0/1
# Batch Loss: 30661.752
# Epoch Avg Loss: 30661.752
# Epoch: 446
# 0 50
# Curr Epoch: 446 Curr Batch: 0/1
# Batch Loss: 31121.137
# Epoch Avg Loss: 31121.137
# Epoch: 447
# 0 50
# Curr Epoch: 447 Curr Batch: 0/1
# Batch Loss: 30351.836
# Epoch Avg Loss: 30351.836
# Epoch: 448
# 0 50
# Curr Epoch: 448 Curr Batch: 0/1
# Batch Loss: 30583.99
# Epoch Avg Loss: 30583.99
# Epoch: 449
# 0 50
# Curr Epoch: 449 Curr Batch: 0/1
# Batch Loss: 29883.074
# Epoch Avg Loss: 29883.074
# Epoch: 450
# 0 50
# Curr Epoch: 450 Curr Batch: 0/1
# Batch Loss: 29396.74
# Epoch Avg Loss: 29396.74
# Epoch: 451
# 0 50
# Curr Epoch: 451 Curr Batch: 0/1
# Batch Loss: 29026.068
# Epoch Avg Loss: 29026.068
# Epoch: 452
# 0 50
# Curr Epoch: 452 Curr Batch: 0/1
# Batch Loss: 28727.22
# Epoch Avg Loss: 28727.22
# Epoch: 453
# 0 50
# Curr Epoch: 453 Curr Batch: 0/1
# Batch Loss: 28706.113
# Epoch Avg Loss: 28706.113
# Epoch: 454
# 0 50
# Curr Epoch: 454 Curr Batch: 0/1
# Batch Loss: 28434.635
# Epoch Avg Loss: 28434.635
# Epoch: 455
# 0 50
# Curr Epoch: 455 Curr Batch: 0/1
# Batch Loss: 28625.408
# Epoch Avg Loss: 28625.408
# Epoch: 456
# 0 50
# Curr Epoch: 456 Curr Batch: 0/1
# Batch Loss: 28304.613
# Epoch Avg Loss: 28304.613
# Epoch: 457
# 0 50
# Curr Epoch: 457 Curr Batch: 0/1
# Batch Loss: 28821.855
# Epoch Avg Loss: 28821.855
# Epoch: 458
# 0 50
# Curr Epoch: 458 Curr Batch: 0/1
# Batch Loss: 28689.96
# Epoch Avg Loss: 28689.96
# Epoch: 459
# 0 50
# Curr Epoch: 459 Curr Batch: 0/1
# Batch Loss: 29054.574
# Epoch Avg Loss: 29054.574
# Epoch: 460
# 0 50
# ...
# Epoch Avg Loss: 14588.367
# Epoch: 3202
# 0 50
# Curr Epoch: 3202 Curr Batch: 0/1
# Batch Loss: 14449.175
# Epoch Avg Loss: 14449.175
# Epoch: 3203
# 0 50
# Curr Epoch: 3203 Curr Batch: 0/1
# Batch Loss: 14664.676
# Epoch Avg Loss: 14664.676
# Epoch: 3204
# 0 50
# Curr Epoch: 3204 Curr Batch: 0/1
# Batch Loss: 14645.34
# Epoch Avg Loss: 14645.34
# Epoch: 3205
# 0 50
# Curr Epoch: 3205 Curr Batch: 0/1
# Batch Loss: 14585.831
# Epoch Avg Loss: 14585.831
# Epoch: 3206
# 0 50
# Curr Epoch: 3206 Curr Batch: 0/1
# Batch Loss: 14866.78
# Epoch Avg Loss: 14866.78
# Epoch: 3207
# 0 50
# Curr Epoch: 3207 Curr Batch: 0/1
# Batch Loss: 14906.881
# Epoch Avg Loss: 14906.881
# Epoch: 3208
# 0 50
# Curr Epoch: 3208 Curr Batch: 0/1
# Batch Loss: 15119.934
# Epoch Avg Loss: 15119.934
# Epoch: 3209
# 0 50
# Curr Epoch: 3209 Curr Batch: 0/1
# Batch Loss: 15522.836
# Epoch Avg Loss: 15522.836
# Epoch: 3210
# 0 50
# Curr Epoch: 3210 Curr Batch: 0/1
# Batch Loss: 15126.116
# Epoch Avg Loss: 15126.116
# Epoch: 3211
# 0 50
# Curr Epoch: 3211 Curr Batch: 0/1
# Batch Loss: 15547.166
# Epoch Avg Loss: 15547.166
# Epoch: 3212
# 0 50
# Curr Epoch: 3212 Curr Batch: 0/1
# Batch Loss: 15615.411
# Epoch Avg Loss: 15615.411
# Epoch: 3213
# 0 50
# Curr Epoch: 3213 Curr Batch: 0/1
# Batch Loss: 15301.44
# Epoch Avg Loss: 15301.44
# Epoch: 3214
# 0 50
# Curr Epoch: 3214 Curr Batch: 0/1
# Batch Loss: 15363.914
# Epoch Avg Loss: 15363.914
# Epoch: 3215
# 0 50
# Curr Epoch: 3215 Curr Batch: 0/1
# Batch Loss: 15407.892
# Epoch Avg Loss: 15407.892
# Epoch: 3216
# 0 50
# Curr Epoch: 3216 Curr Batch: 0/1
# Batch Loss: 15047.191
# Epoch Avg Loss: 15047.191
# Epoch: 3217
# 0 50
# Curr Epoch: 3217 Curr Batch: 0/1
# Batch Loss: 14720.847
# Epoch Avg Loss: 14720.847
# Epoch: 3218
# 0 50
# Curr Epoch: 3218 Curr Batch: 0/1
# Batch Loss: 14568.732
# Epoch Avg Loss: 14568.732
# Epoch: 3219
# 0 50
# Curr Epoch: 3219 Curr Batch: 0/1
# Batch Loss: 14472.5625
# Epoch Avg Loss: 14472.5625
# Epoch: 3220
# 0 50
# Curr Epoch: 3220 Curr Batch: 0/1
# Batch Loss: 14217.492
# Epoch Avg Loss: 14217.492
# Epoch: 3221
# 0 50
# Curr Epoch: 3221 Curr Batch: 0/1
# Batch Loss: 14282.847
# Epoch Avg Loss: 14282.847
# Epoch: 3222
# 0 50
# Curr Epoch: 3222 Curr Batch: 0/1
# Batch Loss: 14680.108
# Epoch Avg Loss: 14680.108
# Epoch: 3223
# 0 50
# Curr Epoch: 3223 Curr Batch: 0/1
# Batch Loss: 14783.343
# Epoch Avg Loss: 14783.343
# Epoch: 3224
# 0 50
# Curr Epoch: 3224 Curr Batch: 0/1
# Batch Loss: 14821.982
# Epoch Avg Loss: 14821.982
# Epoch: 3225
# 0 50
# Curr Epoch: 3225 Curr Batch: 0/1
# Batch Loss: 15109.374
# Epoch Avg Loss: 15109.374
# Epoch: 3226
# 0 50
# Curr Epoch: 3226 Curr Batch: 0/1
# Batch Loss: 14826.729
# Epoch Avg Loss: 14826.729
# Epoch: 3227
# 0 50
# Curr Epoch: 3227 Curr Batch: 0/1
# Batch Loss: 15055.031
# Epoch Avg Loss: 15055.031
# Epoch: 3228
# 0 50
# Curr Epoch: 3228 Curr Batch: 0/1
# Batch Loss: 15437.055
# Epoch Avg Loss: 15437.055
# Epoch: 3229
# 0 50
# Curr Epoch: 3229 Curr Batch: 0/1
# Batch Loss: 15178.852
# Epoch Avg Loss: 15178.852
# Epoch: 3230
# 0 50
# Curr Epoch: 3230 Curr Batch: 0/1
# Batch Loss: 15210.81
# Epoch Avg Loss: 15210.81
# Epoch: 3231
# 0 50
# Curr Epoch: 3231 Curr Batch: 0/1
# Batch Loss: 15190.866
# Epoch Avg Loss: 15190.866
# Epoch: 3232
# 0 50
# Curr Epoch: 3232 Curr Batch: 0/1
# Batch Loss: 15268.763
# Epoch Avg Loss: 15268.763
# Epoch: 3233
# 0 50
# Curr Epoch: 3233 Curr Batch: 0/1
# Batch Loss: 15068.822
# Epoch Avg Loss: 15068.822
# Epoch: 3234
# 0 50
# Curr Epoch: 3234 Curr Batch: 0/1
# Batch Loss: 14743.704
# Epoch Avg Loss: 14743.704
# Epoch: 3235
# 0 50
# Curr Epoch: 3235 Curr Batch: 0/1
# Batch Loss: 14795.055
# Epoch Avg Loss: 14795.055
# Epoch: 3236
# 0 50
# Curr Epoch: 3236 Curr Batch: 0/1
# Batch Loss: 14455.434
# Epoch Avg Loss: 14455.434
# Epoch: 3237
# 0 50
# Curr Epoch: 3237 Curr Batch: 0/1
# Batch Loss: 14406.481
# Epoch Avg Loss: 14406.481
# Epoch: 3238
# 0 50
# Curr Epoch: 3238 Curr Batch: 0/1
# Batch Loss: 14280.378
# Epoch Avg Loss: 14280.378
# Epoch: 3239
# 0 50
# Curr Epoch: 3239 Curr Batch: 0/1
# Batch Loss: 14141.821
# Epoch Avg Loss: 14141.821
# Epoch: 3240
# 0 50
# Curr Epoch: 3240 Curr Batch: 0/1
# Batch Loss: 14139.159
# Epoch Avg Loss: 14139.159
# Epoch: 3241
# 0 50
# Curr Epoch: 3241 Curr Batch: 0/1
# Batch Loss: 14200.095
# Epoch Avg Loss: 14200.095
# Epoch: 3242
# 0 50
# Curr Epoch: 3242 Curr Batch: 0/1
# Batch Loss: 14145.139
# Epoch Avg Loss: 14145.139
# Epoch: 3243
# 0 50
# Curr Epoch: 3243 Curr Batch: 0/1
# Batch Loss: 14215.843
# Epoch Avg Loss: 14215.843
# Epoch: 3244
# 0 50
# Curr Epoch: 3244 Curr Batch: 0/1
# Batch Loss: 14211.69
# Epoch Avg Loss: 14211.69
# Epoch: 3245
# 0 50
# Curr Epoch: 3245 Curr Batch: 0/1
# Batch Loss: 14220.603
# Epoch Avg Loss: 14220.603
# Epoch: 3246
# 0 50
# Curr Epoch: 3246 Curr Batch: 0/1
# Batch Loss: 14250.235
# Epoch Avg Loss: 14250.235
# Epoch: 3247
# 0 50
# Curr Epoch: 3247 Curr Batch: 0/1
# Batch Loss: 14225.107
# Epoch Avg Loss: 14225.107
# Epoch: 3248
# 0 50
# Curr Epoch: 3248 Curr Batch: 0/1
# Batch Loss: 14290.004
# Epoch Avg Loss: 14290.004
# Epoch: 3249
# 0 50
# Curr Epoch: 3249 Curr Batch: 0/1
# Batch Loss: 14414.865
# Epoch Avg Loss: 14414.865
# Epoch: 3250
# 0 50
# Curr Epoch: 3250 Curr Batch: 0/1
# Batch Loss: 14359.17
# Epoch Avg Loss: 14359.17
# Epoch: 3251
# 0 50
# Curr Epoch: 3251 Curr Batch: 0/1
# Batch Loss: 14413.52
# Epoch Avg Loss: 14413.52
# Epoch: 3252
# 0 50
# Curr Epoch: 3252 Curr Batch: 0/1
# Batch Loss: 14494.648
# Epoch Avg Loss: 14494.648
# Epoch: 3253
# 0 50
# Curr Epoch: 3253 Curr Batch: 0/1
# Batch Loss: 14662.25
# Epoch Avg Loss: 14662.25
# Epoch: 3254
# 0 50
# Curr Epoch: 3254 Curr Batch: 0/1
# Batch Loss: 15078.157
# Epoch Avg Loss: 15078.157
# Epoch: 3255
# 0 50
# Curr Epoch: 3255 Curr Batch: 0/1
# Batch Loss: 14836.704
# Epoch Avg Loss: 14836.704
# Epoch: 3256
# 0 50
# Curr Epoch: 3256 Curr Batch: 0/1
# Batch Loss: 15151.916
# Epoch Avg Loss: 15151.916
# Epoch: 3257
# 0 50
# Curr Epoch: 3257 Curr Batch: 0/1
# Batch Loss: 15664.264
# Epoch Avg Loss: 15664.264
# Epoch: 3258
# 0 50
# Curr Epoch: 3258 Curr Batch: 0/1
# Batch Loss: 15919.68
# Epoch Avg Loss: 15919.68
# Epoch: 3259
# 0 50
# Curr Epoch: 3259 Curr Batch: 0/1
# Batch Loss: 15510.903
# Epoch Avg Loss: 15510.903
# Epoch: 3260
# 0 50
# Curr Epoch: 3260 Curr Batch: 0/1
# Batch Loss: 15647.148
# Epoch Avg Loss: 15647.148
# Epoch: 3261
# 0 50
# Curr Epoch: 3261 Curr Batch: 0/1
# Batch Loss: 16041.526
# Epoch Avg Loss: 16041.526
# Epoch: 3262
# 0 50
# Curr Epoch: 3262 Curr Batch: 0/1
# Batch Loss: 15552.395
# Epoch Avg Loss: 15552.395
# Epoch: 3263
# 0 50
# Curr Epoch: 3263 Curr Batch: 0/1
# Batch Loss: 15503.426
# Epoch Avg Loss: 15503.426
# Epoch: 3264
# 0 50
# Curr Epoch: 3264 Curr Batch: 0/1
# Batch Loss: 15745.025
# Epoch Avg Loss: 15745.025
# Epoch: 3265
# 0 50
# Curr Epoch: 3265 Curr Batch: 0/1
# Batch Loss: 14752.097
# Epoch Avg Loss: 14752.097
# Epoch: 3266
# 0 50
# Curr Epoch: 3266 Curr Batch: 0/1
# Batch Loss: 14826.296
# Epoch Avg Loss: 14826.296
# Epoch: 3267
# 0 50
# Curr Epoch: 3267 Curr Batch: 0/1
# Batch Loss: 14606.919
# Epoch Avg Loss: 14606.919
# Epoch: 3268
# 0 50
# Curr Epoch: 3268 Curr Batch: 0/1
# Batch Loss: 14269.267
# Epoch Avg Loss: 14269.267
# Epoch: 3269
# 0 50
# Curr Epoch: 3269 Curr Batch: 0/1
# Batch Loss: 14447.53
# Epoch Avg Loss: 14447.53
# Epoch: 3270
# 0 50
# Curr Epoch: 3270 Curr Batch: 0/1
# Batch Loss: 14502.522
# Epoch Avg Loss: 14502.522
# Epoch: 3271
# 0 50
# Curr Epoch: 3271 Curr Batch: 0/1
# Batch Loss: 14366.487
# Epoch Avg Loss: 14366.487
# Epoch: 3272
# 0 50
# Curr Epoch: 3272 Curr Batch: 0/1
# Batch Loss: 14204.173
# Epoch Avg Loss: 14204.173
# Epoch: 3273
# 0 50
# Curr Epoch: 3273 Curr Batch: 0/1
# Batch Loss: 14347.091
# Epoch Avg Loss: 14347.091
# Epoch: 3274
# 0 50
# Curr Epoch: 3274 Curr Batch: 0/1
# Batch Loss: 14291.139
# Epoch Avg Loss: 14291.139
# Epoch: 3275
# 0 50
# Curr Epoch: 3275 Curr Batch: 0/1
# Batch Loss: 14101.619
# Epoch Avg Loss: 14101.619
# Epoch: 3276
# 0 50
# Curr Epoch: 3276 Curr Batch: 0/1
# Batch Loss: 13962.716
# Epoch Avg Loss: 13962.716
# Epoch: 3277
# 0 50
# Curr Epoch: 3277 Curr Batch: 0/1
# Batch Loss: 14047.778
# Epoch Avg Loss: 14047.778
# Epoch: 3278
# 0 50
# Curr Epoch: 3278 Curr Batch: 0/1
# Batch Loss: 14090.138
# Epoch Avg Loss: 14090.138
# Epoch: 3279
# 0 50
# Curr Epoch: 3279 Curr Batch: 0/1
# Batch Loss: 14105.065
# Epoch Avg Loss: 14105.065
# Epoch: 3280
# 0 50
# Curr Epoch: 3280 Curr Batch: 0/1
# Batch Loss: 14028.394
# Epoch Avg Loss: 14028.394
# Epoch: 3281
# 0 50
# Curr Epoch: 3281 Curr Batch: 0/1
# Batch Loss: 13995.639
# Epoch Avg Loss: 13995.639
# Epoch: 3282
# 0 50
# Curr Epoch: 3282 Curr Batch: 0/1
# Batch Loss: 14134.192
# Epoch Avg Loss: 14134.192
# Epoch: 3283
# 0 50
# Curr Epoch: 3283 Curr Batch: 0/1
# Batch Loss: 14268.204
# Epoch Avg Loss: 14268.204
# Epoch: 3284
# 0 50
# Curr Epoch: 3284 Curr Batch: 0/1
# Batch Loss: 14308.111
# Epoch Avg Loss: 14308.111
# Epoch: 3285
# 0 50
# Curr Epoch: 3285 Curr Batch: 0/1
# Batch Loss: 14817.595
# Epoch Avg Loss: 14817.595
# Epoch: 3286
# 0 50
# Curr Epoch: 3286 Curr Batch: 0/1
# Batch Loss: 15231.597
# Epoch Avg Loss: 15231.597
# Epoch: 3287
# 0 50
# Curr Epoch: 3287 Curr Batch: 0/1
# Batch Loss: 14768.286
# Epoch Avg Loss: 14768.286
# Epoch: 3288
# 0 50
# Curr Epoch: 3288 Curr Batch: 0/1
# Batch Loss: 15399.38
# Epoch Avg Loss: 15399.38
# Epoch: 3289
# 0 50
# Curr Epoch: 3289 Curr Batch: 0/1
# Batch Loss: 16605.252
# Epoch Avg Loss: 16605.252
# Epoch: 3290
# 0 50
# Curr Epoch: 3290 Curr Batch: 0/1
# Batch Loss: 15863.434
# Epoch Avg Loss: 15863.434
# Epoch: 3291
# 0 50
# Curr Epoch: 3291 Curr Batch: 0/1
# Batch Loss: 16410.56
# Epoch Avg Loss: 16410.56
# Epoch: 3292
# 0 50
# Curr Epoch: 3292 Curr Batch: 0/1
# Batch Loss: 16409.074
# Epoch Avg Loss: 16409.074
# Epoch: 3293
# 0 50
# Curr Epoch: 3293 Curr Batch: 0/1
# Batch Loss: 15894.782
# Epoch Avg Loss: 15894.782
# Epoch: 3294
# 0 50
# Curr Epoch: 3294 Curr Batch: 0/1
# Batch Loss: 15594.034
# Epoch Avg Loss: 15594.034
# Epoch: 3295
# 0 50
# Curr Epoch: 3295 Curr Batch: 0/1
# Batch Loss: 15013.388
# Epoch Avg Loss: 15013.388
# Epoch: 3296
# 0 50
# Curr Epoch: 3296 Curr Batch: 0/1
# Batch Loss: 15116.522
# Epoch Avg Loss: 15116.522
# Epoch: 3297
# 0 50
# Curr Epoch: 3297 Curr Batch: 0/1
# Batch Loss: 14510.5625
# Epoch Avg Loss: 14510.5625
# Epoch: 3298
# 0 50
# Curr Epoch: 3298 Curr Batch: 0/1
# Batch Loss: 14494.187
# Epoch Avg Loss: 14494.187
# Epoch: 3299
# 0 50
# Curr Epoch: 3299 Curr Batch: 0/1
# Batch Loss: 14375.722
# Epoch Avg Loss: 14375.722
# Epoch: 3300
# 0 50
# Curr Epoch: 3300 Curr Batch: 0/1
# Batch Loss: 13890.805
# Epoch Avg Loss: 13890.805
# Epoch: 3301
# 0 50
# Curr Epoch: 3301 Curr Batch: 0/1
# Batch Loss: 13875.192
# Epoch Avg Loss: 13875.192
# Epoch: 3302
# 0 50
# Curr Epoch: 3302 Curr Batch: 0/1
# Batch Loss: 13961.527
# Epoch Avg Loss: 13961.527
# Epoch: 3303
# 0 50
# Curr Epoch: 3303 Curr Batch: 0/1
# Batch Loss: 13920.826
# Epoch Avg Loss: 13920.826
# Epoch: 3304
# 0 50
# Curr Epoch: 3304 Curr Batch: 0/1
# Batch Loss: 13792.312
# Epoch Avg Loss: 13792.312
# Epoch: 3305
# 0 50
# Curr Epoch: 3305 Curr Batch: 0/1
# Batch Loss: 13818.032
# Epoch Avg Loss: 13818.032
# Epoch: 3306
# 0 50
# Curr Epoch: 3306 Curr Batch: 0/1
# Batch Loss: 13867.678
# Epoch Avg Loss: 13867.678
# Epoch: 3307
# 0 50
# Curr Epoch: 3307 Curr Batch: 0/1
# Batch Loss: 13876.018
# Epoch Avg Loss: 13876.018
# Epoch: 3308
# 0 50
# Curr Epoch: 3308 Curr Batch: 0/1
# Batch Loss: 13826.099
# Epoch Avg Loss: 13826.099
# Epoch: 3309
# 0 50
# Curr Epoch: 3309 Curr Batch: 0/1
# Batch Loss: 13957.415
# Epoch Avg Loss: 13957.415
# Epoch: 3310
# 0 50
# Curr Epoch: 3310 Curr Batch: 0/1
# Batch Loss: 14133.603
# Epoch Avg Loss: 14133.603
# Epoch: 3311
# 0 50
# Curr Epoch: 3311 Curr Batch: 0/1
# Batch Loss: 14235.539
# Epoch Avg Loss: 14235.539
# Epoch: 3312
# 0 50
# Curr Epoch: 3312 Curr Batch: 0/1
# Batch Loss: 14319.146
# Epoch Avg Loss: 14319.146
# Epoch: 3313
# 0 50
# Curr Epoch: 3313 Curr Batch: 0/1
# Batch Loss: 14500.548
# Epoch Avg Loss: 14500.548
# Epoch: 3314
# 0 50
# Curr Epoch: 3314 Curr Batch: 0/1
# Batch Loss: 14779.762
# Epoch Avg Loss: 14779.762
# Epoch: 3315
# 0 50
# Curr Epoch: 3315 Curr Batch: 0/1
# Batch Loss: 14591.515
# Epoch Avg Loss: 14591.515
# Epoch: 3316
# 0 50
# Curr Epoch: 3316 Curr Batch: 0/1
# Batch Loss: 14866.321
# Epoch Avg Loss: 14866.321
# Epoch: 3317
# 0 50
# Curr Epoch: 3317 Curr Batch: 0/1
# Batch Loss: 15475.473
# Epoch Avg Loss: 15475.473
# Epoch: 3318
# 0 50
# Curr Epoch: 3318 Curr Batch: 0/1
# Batch Loss: 15361.303
# Epoch Avg Loss: 15361.303
# Epoch: 3319
# 0 50
# Curr Epoch: 3319 Curr Batch: 0/1
# Batch Loss: 15654.161
# Epoch Avg Loss: 15654.161
# Epoch: 3320
# 0 50
# Curr Epoch: 3320 Curr Batch: 0/1
# Batch Loss: 16520.28
# Epoch Avg Loss: 16520.28
# Epoch: 3321
# 0 50
# Curr Epoch: 3321 Curr Batch: 0/1
# Batch Loss: 16177.688
# Epoch Avg Loss: 16177.688
# Epoch: 3322
# 0 50
# Curr Epoch: 3322 Curr Batch: 0/1
# Batch Loss: 15880.057
# Epoch Avg Loss: 15880.057
# Epoch: 3323
# 0 50
# Curr Epoch: 3323 Curr Batch: 0/1
# Batch Loss: 15791.363
# Epoch Avg Loss: 15791.363
# Epoch: 3324
# 0 50
# Curr Epoch: 3324 Curr Batch: 0/1
# Batch Loss: 14810.086
# Epoch Avg Loss: 14810.086
# Epoch: 3325
# 0 50
# Curr Epoch: 3325 Curr Batch: 0/1
# Batch Loss: 14474.095
# Epoch Avg Loss: 14474.095
# Epoch: 3326
# 0 50
# Curr Epoch: 3326 Curr Batch: 0/1
# Batch Loss: 14135.813
# Epoch Avg Loss: 14135.813
# Epoch: 3327
# 0 50
# Curr Epoch: 3327 Curr Batch: 0/1
# Batch Loss: 13905.776
# Epoch Avg Loss: 13905.776
# Epoch: 3328
# 0 50
# Curr Epoch: 3328 Curr Batch: 0/1
# Batch Loss: 13763.416
# Epoch Avg Loss: 13763.416
# Epoch: 3329
# 0 50
# Curr Epoch: 3329 Curr Batch: 0/1
# Batch Loss: 13618.216
# Epoch Avg Loss: 13618.216
# Epoch: 3330
# 0 50
# Curr Epoch: 3330 Curr Batch: 0/1
# Batch Loss: 13554.775
# Epoch Avg Loss: 13554.775
# Epoch: 3331
# 0 50
# Curr Epoch: 3331 Curr Batch: 0/1
# Batch Loss: 13571.47
# Epoch Avg Loss: 13571.47
# Epoch: 3332
# 0 50
# Curr Epoch: 3332 Curr Batch: 0/1
# Batch Loss: 13556.893
# Epoch Avg Loss: 13556.893
# Epoch: 3333
# 0 50
# Curr Epoch: 3333 Curr Batch: 0/1
# Batch Loss: 13631.914
# Epoch Avg Loss: 13631.914
# Epoch: 3334
# 0 50
# Curr Epoch: 3334 Curr Batch: 0/1
# Batch Loss: 13882.102
# Epoch Avg Loss: 13882.102
# Epoch: 3335
# 0 50
# Curr Epoch: 3335 Curr Batch: 0/1
# Batch Loss: 14062.762
# Epoch Avg Loss: 14062.762
# Epoch: 3336
# 0 50
# Curr Epoch: 3336 Curr Batch: 0/1
# Batch Loss: 14011.273
# Epoch Avg Loss: 14011.273
# Epoch: 3337
# 0 50
# Curr Epoch: 3337 Curr Batch: 0/1
# Batch Loss: 14204.304
# Epoch Avg Loss: 14204.304
# Epoch: 3338
# 0 50
# Curr Epoch: 3338 Curr Batch: 0/1
# Batch Loss: 14424.727
# Epoch Avg Loss: 14424.727
# Epoch: 3339
# 0 50
# Curr Epoch: 3339 Curr Batch: 0/1
# Batch Loss: 14243.33
# Epoch Avg Loss: 14243.33
# Epoch: 3340
# 0 50
# Curr Epoch: 3340 Curr Batch: 0/1
# Batch Loss: 14231.3125
# Epoch Avg Loss: 14231.3125
# Epoch: 3341
# 0 50
# Curr Epoch: 3341 Curr Batch: 0/1
# Batch Loss: 14393.182
# Epoch Avg Loss: 14393.182
# Epoch: 3342
# 0 50
# Curr Epoch: 3342 Curr Batch: 0/1
# Batch Loss: 14368.348
# Epoch Avg Loss: 14368.348
# Epoch: 3343
# 0 50
# Curr Epoch: 3343 Curr Batch: 0/1
# Batch Loss: 14940.543
# Epoch Avg Loss: 14940.543
# Epoch: 3344
# 0 50
# Curr Epoch: 3344 Curr Batch: 0/1
# Batch Loss: 15390.14
# Epoch Avg Loss: 15390.14
# Epoch: 3345
# 0 50
# Curr Epoch: 3345 Curr Batch: 0/1
# Batch Loss: 14692.733
# Epoch Avg Loss: 14692.733
# Epoch: 3346
# 0 50
# Curr Epoch: 3346 Curr Batch: 0/1
# Batch Loss: 15241.0
# Epoch Avg Loss: 15241.0
# Epoch: 3347
# 0 50
# Curr Epoch: 3347 Curr Batch: 0/1
# Batch Loss: 16168.767
# Epoch Avg Loss: 16168.767
# Epoch: 3348
# 0 50
# Curr Epoch: 3348 Curr Batch: 0/1
# Batch Loss: 14756.969
# Epoch Avg Loss: 14756.969
# Epoch: 3349
# 0 50
# Curr Epoch: 3349 Curr Batch: 0/1
# Batch Loss: 15134.365
# Epoch Avg Loss: 15134.365
# Epoch: 3350
# 0 50
# Curr Epoch: 3350 Curr Batch: 0/1
# Batch Loss: 15499.73
# Epoch Avg Loss: 15499.73
# Epoch: 3351
# 0 50
# Curr Epoch: 3351 Curr Batch: 0/1
# Batch Loss: 15407.457
# Epoch Avg Loss: 15407.457
# Epoch: 3352
# 0 50
# Curr Epoch: 3352 Curr Batch: 0/1
# Batch Loss: 14962.537
# Epoch Avg Loss: 14962.537
# Epoch: 3353
# 0 50
# Curr Epoch: 3353 Curr Batch: 0/1
# Batch Loss: 14728.594
# Epoch Avg Loss: 14728.594
# Epoch: 3354
# 0 50
# Curr Epoch: 3354 Curr Batch: 0/1
# Batch Loss: 14982.586
# Epoch Avg Loss: 14982.586
# Epoch: 3355
# 0 50
# Curr Epoch: 3355 Curr Batch: 0/1
# Batch Loss: 14678.876
# Epoch Avg Loss: 14678.876
# Epoch: 3356
# 0 50
# Curr Epoch: 3356 Curr Batch: 0/1
# Batch Loss: 14723.553
# Epoch Avg Loss: 14723.553
# Epoch: 3357
# 0 50
# Curr Epoch: 3357 Curr Batch: 0/1
# Batch Loss: 14536.129
# Epoch Avg Loss: 14536.129
# Epoch: 3358
# 0 50
# Curr Epoch: 3358 Curr Batch: 0/1
# Batch Loss: 14089.683
# Epoch Avg Loss: 14089.683
# Epoch: 3359
# 0 50
# Curr Epoch: 3359 Curr Batch: 0/1
# Batch Loss: 14273.308
# Epoch Avg Loss: 14273.308
# Epoch: 3360
# 0 50
# Curr Epoch: 3360 Curr Batch: 0/1
# Batch Loss: 14118.805
# Epoch Avg Loss: 14118.805
# Epoch: 3361
# 0 50
# Curr Epoch: 3361 Curr Batch: 0/1
# Batch Loss: 13803.683
# Epoch Avg Loss: 13803.683
# Epoch: 3362
# 0 50
# Curr Epoch: 3362 Curr Batch: 0/1
# Batch Loss: 13767.352
# Epoch Avg Loss: 13767.352
# Epoch: 3363
# 0 50
# Curr Epoch: 3363 Curr Batch: 0/1
# Batch Loss: 13734.582
# Epoch Avg Loss: 13734.582
# Epoch: 3364
# 0 50
# Curr Epoch: 3364 Curr Batch: 0/1
# Batch Loss: 13832.062
# Epoch Avg Loss: 13832.062
# Epoch: 3365
# 0 50

# %% [markdown]
# # 중간 체크포인트부터

# %%
cur_epoch = 5000
##### Run training
with tf.Session() as sess:
	init.run()
	### saver 만들기
	saver = tf.train.Saver()
	sess.run(tf.global_variables_initializer())
	print('processing...')
	sample_rate = process_data.file_to_data(sess)
	ckpt_path = saver.restore(sess, f"/content/drive/My Drive/tobigs/dnn_auto_encoder/saved/train{cur_epoch}")
	print('processing Done!')

	for epoch in range(cur_epoch+1,epochs):
		epoch_loss = []
		print("Epoch: " + str(epoch))
		for i in range(batches):
			ch1_song, ch2_song, sample_rate = next_batch2(i, batch_size, sample_rate,sess)
			total_songs = np.hstack([ch1_song, ch2_song])
			batch_loss = []

			for j in range(len(total_songs)):
				x_batch = total_songs[j]
				_, l = sess.run([training_op, loss], feed_dict={X:x_batch})
				batch_loss.append(l)
				# print("Song loss: " + str(l))

			print("Curr Epoch: " + str(epoch) + " Curr Batch: " + str(i) + "/"+ str(batches))
			print("Batch Loss: " + str(np.mean(batch_loss)))
			epoch_loss.append(np.mean(batch_loss))
			
		print("Epoch Avg Loss: " + str(np.mean(epoch_loss)))

		if epoch % 200 == 0:
			ckpt_path = saver.save(sess, f'/content/drive/My Drive/tobigs/dnn_auto_encoder/saved/train{epoch}')

	ckpt_path = saver.save(sess, "/content/drive/My Drive/tobigs/dnn_auto_encoder/saved/train")
#9:10~9:30 100 epoch 간다.

# %% [markdown]
# # TEST 결과 확인

# %%
print(len(process_data.file_arr))
print(process_data.file_arr[5])
# Out:
# 52
# /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/5.wav

# %%
##### test train 없는데이터로(200 epoch)
sample_rate = 44100
epoch = 1500
data_num = 51
from scipy.fftpack import rfft, irfft
from tensorflow.contrib import ffmpeg
import json 

with tf.Session() as sess:
	init.run()
	### saver 만들기
	saver = tf.train.Saver()
	sess.run(tf.global_variables_initializer())
	
	# sample_rate = process_data.file_to_data(sess)
	ckpt_path = saver.restore(sess, f"/content/drive/My Drive/tobigs/dnn_auto_encoder/saved/train{epoch}")

	# 학습하지 않은 데이터 받기
	ch1_song_new, ch2_song_new, sample_rate_new = next_batch(data_num, 1, sess)
	x_batch = np.hstack([ch1_song_new, ch2_song_new])[0]
	print("Sample rate: " + str(sample_rate_new)) 

	orig_song = []
	full_song = []
	evaluation = outputs.eval(feed_dict={X: x_batch})
	print("Output: " + str(evaluation)) 
	full_song.append(evaluation)
	orig_song.append(x_batch)
	print(len(full_song), len(full_song[0]))
	# Merge the nested arrays
	# 1*856 짜리인걸 한 array로 바꾼다!
	orig_song = np.hstack(orig_song)
	full_song = np.hstack(full_song)
	
	print('shape')
	print(orig_song.shape, full_song.shape)

	# Compute and split the channels
	orig_song_ch1 = orig_song[:math.floor(len(orig_song)/2)]
	orig_song_ch2 = orig_song[math.floor(len(orig_song)/2):]
	full_song_ch1 = full_song[:math.floor(len(full_song)/2)]
	full_song_ch2 = full_song[math.floor(len(full_song)/2):]
	print('next')
	print(np.hstack(full_song_ch1).shape, np.hstack(orig_song_ch1).shape)
	# print(np.hstack(np.hstack(full_song_ch1)).shape, full_song_ch1.shape)
	
	# Save both the untouched song and reconstructed song to the 'output' folder
	# process_data.save_to_wav(full_song_ch1, full_song_ch2, sample_rate, orig_song_ch1, orig_song_ch2, epoch, 'output', sess)


	# audio_arr_ch1 = irfft(np.hstack(np.hstack(full_song_ch1)))
	# audio_arr_ch2 = irfft(np.hstack(np.hstack(full_song_ch2)))

	# print('reconstruced done')
	# original_song_ch1 = irfft(np.hstack(np.hstack(orig_song_ch1)))
	# original_song_ch2 = irfft(np.hstack(np.hstack(orig_song_ch2)))

	audio_arr_ch1 = irfft(np.hstack(full_song_ch1))
	audio_arr_ch2 = irfft(np.hstack(full_song_ch2))

	print('reconstruced done')
	# original_song_ch1 = irfft(np.hstack(orig_song_ch1))
	# original_song_ch2 = irfft(np.hstack(orig_song_ch2))


	print('irfft done')
	# original_song = np.hstack(np.array((original_song_ch1, original_song_ch2)).T)
	audio_arr = np.hstack(np.array((audio_arr_ch1, audio_arr_ch2)).T)

	# print(original_song)
	w = np.linspace(0, sample_rate, len(audio_arr))
	w = w[0:len(audio_arr)]


	cols = 2
	rows = math.floor(len(audio_arr)/2)
	audio_arr = audio_arr.reshape(rows, cols)
	# original_song = original_song.reshape(rows, cols)

	wav_encoder = ffmpeg.encode_audio(
		audio_arr, file_format='wav', samples_per_second=sample_rate)
	# wav_encoder_orig = ffmpeg.encode_audio(
	# 	original_song, file_format='wav', samples_per_second=sample_rate)

	wav_file = sess.run(wav_encoder)
	# wav_orig = sess.run(wav_encoder_orig)
	open(f'/content/drive/My Drive/tobigs/dnn_auto_encoder/output/out_{data_num}_{epoch}.wav', 'wb').write(wav_file)
	# open('output/wav_orig.wav', 'wb').write(wav_orig)

# %%
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/tobigs/dnn_auto_encoder/saved/train1500
# 51 1
# Returning File: /content/drive/My Drive/tobigs/dnn_auto_encoder/music_makes_one/99.wav
# Sample rate: 44100
# Output: [[-7.72812012e+02 -1.94946014e+02 -3.57272552e+02 ...  1.61969681e+02
#    1.49675430e+02 -3.50217957e+02]
#  [ 8.55272034e+02 -1.45860925e+03 -8.96970947e+02 ...  1.15310959e+02
#   -9.91639343e+02 -2.85739960e+02]
#  [-2.74825409e+02 -1.36053406e+02  1.18918304e+02 ... -7.69390488e+01
#    7.71388092e+01  2.08782700e+02]
#  ...
#  [ 2.98753202e-01 -7.69713223e-01  4.42849487e-01 ...  1.98937714e-01
#   -9.37646747e-01  2.60397077e-01]
#  [ 2.70886093e-01 -7.29571640e-01  4.55957651e-01 ...  1.96081042e-01
#   -9.25953031e-01  2.50121117e-01]
#  [ 3.47148836e-01 -7.29793251e-01  4.79579270e-01 ...  1.74841568e-01
#   -9.30139661e-01  2.23104119e-01]]
# 1 856
# shape
# (856, 12348) (856, 12348)
# next
# (5284944,) (5284944,)
# reconstruced done
# irfft done

# %% [markdown]
# # test train에 있는 데이터로

# %%
##### test train 있는 데이터로(200 epoch)
sample_rate = 44100
epoch = 5000
data_num = 3
from scipy.fftpack import rfft, irfft
from tensorflow.contrib import ffmpeg
import json 

with tf.Session() as sess:
	init.run()
	### saver 만들기
	saver = tf.train.Saver()
	sess.run(tf.global_variables_initializer())
	
	# sample_rate = process_data.file_to_data(sess)
	ckpt_path = saver.restore(sess, f"/content/drive/My Drive/tobigs/dnn_auto_encoder/saved/train{epoch}")

	# 학습 된 곡   받기
	ch1_song_new, ch2_song_new, sample_rate_new = next_batch(2, 1, sess)
	x_batch = np.hstack([ch1_song_new, ch2_song_new])[0]
	print("Sample rate: " + str(sample_rate_new)) 

	orig_song = []
	full_song = []
	evaluation = outputs.eval(feed_dict={X: x_batch})
	print("Output: " + str(evaluation)) 
	full_song.append(evaluation)
	orig_song.append(x_batch)
	print(len(full_song), len(full_song[0]))
	# Merge the nested arrays
	# 1*856 짜리인걸 한 array로 바꾼다!
	orig_song = np.hstack(orig_song)
	full_song = np.hstack(full_song)
	
	print('shape')
	print(orig_song.shape, full_song.shape)

	# Compute and split the channels
	orig_song_ch1 = orig_song[:math.floor(len(orig_song)/2)]
	orig_song_ch2 = orig_song[math.floor(len(orig_song)/2):]
	full_song_ch1 = full_song[:math.floor(len(full_song)/2)]
	full_song_ch2 = full_song[math.floor(len(full_song)/2):]
	print('next')
	print(np.hstack(full_song_ch1).shape, np.hstack(orig_song_ch1).shape)
	# print(np.hstack(np.hstack(full_song_ch1)).shape, full_song_ch1.shape)
	
	# Save both the untouched song and reconstructed song to the 'output' folder
	# process_data.save_to_wav(full_song_ch1, full_song_ch2, sample_rate, orig_song_ch1, orig_song_ch2, epoch, 'output', sess)


	# audio_arr_ch1 = irfft(np.hstack(np.hstack(full_song_ch1)))
	# audio_arr_ch2 = irfft(np.hstack(np.hstack(full_song_ch2)))

	# print('reconstruced done')
	# original_song_ch1 = irfft(np.hstack(np.hstack(orig_song_ch1)))
	# original_song_ch2 = irfft(np.hstack(np.hstack(orig_song_ch2)))

	audio_arr_ch1 = irfft(np.hstack(full_song_ch1))
	audio_arr_ch2 = irfft(np.hstack(full_song_ch2))

	print('reconstruced done')
	# original_song_ch1 = irfft(np.hstack(orig_song_ch1))
	# original_song_ch2 = irfft(np.hstack(orig_song_ch2))


	print('irfft done')
	# original_song = np.hstack(np.array((original_song_ch1, original_song_ch2)).T)
	audio_arr = np.hstack(np.array((audio_arr_ch1, audio_arr_ch2)).T)

	# print(original_song)
	w = np.linspace(0, sample_rate, len(audio_arr))
	w = w[0:len(audio_arr)]


	cols = 2
	rows = math.floor(len(audio_arr)/2)
	audio_arr = audio_arr.reshape(rows, cols)
	# original_song = original_song.reshape(rows, cols)

	wav_encoder = ffmpeg.encode_audio(
		audio_arr, file_format='wav', samples_per_second=sample_rate)
	# wav_encoder_orig = ffmpeg.encode_audio(
	# 	original_song, file_format='wav', samples_per_second=sample_rate)

	wav_file = sess.run(wav_encoder)
	# wav_orig = sess.run(wav_encoder_orig)
	open(f'/content/drive/My Drive/tobigs/dnn_auto_encoder/output/out_{data_num}_{epoch}.wav', 'wb').write(wav_file)
	# open('output/wav_orig.wav', 'wb').write(wav_orig)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-0a0652ffba9b> in <module>()
#      13
#      14         # sample_rate = process_data.file_to_data(sess)
# ---> 15         ckpt_path = saver.restore(sess, f"/content/drive/My Drive/tobigs/dnn_auto_encoder/saved/train{epoch}")
#      16
#      17         # 학습 된 곡   받기
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py in restore(self, sess, save_path)
#    1280     if not checkpoint_management.checkpoint_exists_internal(checkpoint_prefix):
#    1281       raise ValueError("The passed save_path is not a valid checkpoint: " +
# -> 1282                        checkpoint_prefix)
#    1283
#    1284     logging.info("Restoring parameters from %s", checkpoint_prefix)
#
# ValueError: The passed save_path is not a valid checkpoint: /content/drive/My Drive/tobigs/dnn_auto_encoder/saved/train5000
