# %% [markdown]
# # 드라이브 마운트 & 환경설정

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# 라이브러리 설치
# !pip install pyworld==0.2.4
# Out:
# ...
#      |████████████████████████████████| 81kB 2.4MB/s
# ...
#   Created wheel for pyworld: filename=pyworld-0.2.4-cp36-cp36m-linux_x86_64.whl size=617993 sha256=fd8b0d222b9b82cf5ec80c01c58cd2041520927b02bab5669855edf098d8f36e
#   Stored in directory: /root/.cache/pip/wheels/06/f9/b0/8a8b49ebc596329b34ee06798f192c27db09f42aff16a1cc82
# Successfully built pyworld
# ...

# %%
# 처음 하시는 분이면 git clone 명령어 주석해제한 다음에 실행할 것

# % cd /content/drive/My Drive/
# !git clone https://github.com/sora-12/Tobigs_music_project # 코드 다운


% cd /content/drive/My Drive/Tobigs_music_project/Vocal_Style_Transfer
# !ls # 코드가 제대로 다운 받아졌는지 확인
# Out:
# /content/drive/My Drive
# fatal: destination path 'Tobigs_music_project' already exists and is not an empty directory.
# /content/drive/My Drive/Tobigs_music_project/Vocal_Style_Transfer
# config.py	data	 model		README.md  train.py
# cycle_began.py	example  preprocess.py	sample	   Utils
# cyclegan.py	log	 __pycache__	test.py

# %% [markdown]
# > # 주의사항 꼭 읽고 진행해 주세요!
#
# ---
#
# > # train 전 주의사항
#
# - data/train 폴더에 A, B에 각각 원하는 가수의 vocal만 들어간 데이터를 넣어주세요.
# - data 폴더에 .npz, pickle파일이 있으면 지워주세요.
# - model 폴더도 비워주세요.
# - 런타임 환경이 GPU인지 확인해주세요.
#
# ---
#
# > # train 중 주의사항
#
# - preprocess가 원래 오래 걸립니다... 대기 부탁드립니다... data폴더에 .npz파일이랑 pickle파일 만들어지면 완성 된 겁니다.
# - 매 100에폭마다 모델 체크포인트와 웨이트를 저장합니다. 1 ~ 2기가 하는 용량이니 구글드라이브 용량이 부족하면 지우면서 진행해주시길 바랍니다. (meta, index, data 3개의 파일이 한 세트 입니다.)
# - 중간에 종료되어도 프리프로세싱 완료 파일이랑 체크포인트 불러와 진행하기 때문에 걱정안하셔도 됩니다.
# - 코드 수정하셨으면 꼬옥! 런타임 초기화 하시고 실행해주시기 바랍니다. 동기화가 올바로 안될 가능성이 크기 때문입니다!
#
# ---
#
# > # test 주의사항
#
# - data/test폴더에 a가수, b가수의 파일 둘다 넣으셔서 만드십시오. 아직 A->B, B->A 가 헷갈립니다..
# - sample 폴더에 완성파일이 만들어 질겁니다.
#
# ---
#
# #### 각자 하이퍼 파라미터 어떻게 해서 돌렸는지, 어떤게 좋은 성능을 보였는지 안좋은 성능을 보였는지 기록하면서 공유할 것!

# %% [markdown]
# # 트레인

# %%
# data/train/A, B에 각각 mr제거된 vocal파일 담아두기
# !python train.py
# Out:
# Constructing MCEPs....
# Wave Loading Complete
# Wave Loading Complete
# Decompose Generator Create!
# Encoding.......

# %% [markdown]
# # 테스트

# %%
# !python test.py
